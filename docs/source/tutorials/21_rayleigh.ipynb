# %% [markdown]
# (rayleigh)=
# # Part I: Rayleigh

# %%
import bayesbay as bb
from bayesbay.discretization import Voronoi1D
import numpy as np
import matplotlib.pyplot as plt
from disba import PhaseDispersion
np.random.seed(30)

# %%
THICKNESS = np.array([10, 10, 15, 20, 20, 20, 20, 20, 0])
VS = np.array([3.38, 3.44, 3.66, 4.25, 4.35, 4.32, 4.315, 4.38, 4.5])
VP_VS = 1.77
VP = VS * VP_VS
RHO = 0.32 * VP + 0.77
PERIODS = np.geomspace(3, 80, 20)
RAYLEIGH_STD = 0.02

# %%
def initialize_vs(param, positions=None):
    vmin, vmax = param.get_vmin_vmax(positions)
    sorted_vals = np.sort(np.random.uniform(vmin, vmax, positions.size))
    return sorted_vals

vs = bb.prior.UniformPrior(name="vs", 
                                    vmin=[2.2, 2.8, 3.3, 4], 
                                    vmax=[3.9, 4.6, 4.8, 5], 
                                    position=[0, 20, 60, 150],
                                    perturb_std=0.15)
vs.set_custom_initialize(initialize_vs)

# %%
pd = PhaseDispersion(THICKNESS, VP, VS, RHO)
phase_vel = pd(PERIODS, mode=0, wave="rayleigh").velocity
d_obs = phase_vel + np.random.normal(0, RAYLEIGH_STD, phase_vel.size)

# %%
# For plotting the prior
depth_prior = np.linspace(0, 200)
vmin_prior, vmax_prior = vs.get_vmin_vmax(depth_prior)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4), gridspec_kw={'width_ratios': [1, 2.5]})
ax1.fill_betweenx(depth_prior, vmin_prior, vmax_prior, alpha=0.2, label='Prior')
Voronoi1D.plot_tessellation(THICKNESS, 
                            VS, 
                            label='True Vs', 
                            ax=ax1, 
                            color='k', 
                            lw=2, 
                            input_type='extents')
ax1.set_xlabel('Vs [km/s]')
ax1.set_ylabel('Depth [km]')
ax1.set_ylim(np.cumsum(THICKNESS)[-1] + max(THICKNESS), 0)
ax1.grid()
ax1.legend()

ax2.plot(PERIODS, phase_vel, 'r--', label='Rayleigh (true Vs)', lw=0.5)
ax2.plot(PERIODS, d_obs, 'ro', label='Rayleigh obs.')
ax2.set_xlabel('Period [s]')
ax2.set_ylabel('Phase velocity [km/s]')
ax2.grid()
ax2.legend()

plt.tight_layout(w_pad=2)
plt.show()

# %%
voronoi = Voronoi1D(
    name="voronoi", 
    vmin=0,
    vmax=150,
    perturb_std=10,
    n_dimensions=None, 
    n_dimensions_min=4,
    n_dimensions_max=15,
    parameters=[vs], 
    birth_from='neighbour'
)
parameterization = bb.parameterization.Parameterization(voronoi)

# %%
def forward_sw(state):
    voronoi = state["voronoi"]
    voronoi_sites = voronoi["discretization"]
    thickness = Voronoi1D.compute_cell_extents(voronoi_sites)
    vs = voronoi["vs"]
    vp = vs * VP_VS
    rho = 0.32 * vp + 0.77
    pd = PhaseDispersion(thickness, vp, vs, rho)
    d_pred = pd(PERIODS, mode=0, wave="rayleigh").velocity
    return d_pred

# %%
target = bb.Target("rayleigh", 
                   d_obs, 
                   std_min=0.001, 
                   std_max=0.1, 
                   std_perturb_std=0.002)

# %%
log_likelihood = bb.LogLikelihood(targets=target, fwd_functions=forward_sw)

inversion = bb.BayesianInversion(
    parameterization=parameterization, 
    log_likelihood=log_likelihood,
    n_chains=20
)
inversion.run(
    sampler=None, 
    n_iterations=350_000, 
    burnin_iterations=75_000, 
    save_every=150,
    verbose=False
)

# %%
for chain in inversion.chains:
    chain.print_statistics()
# Out:
# Chain ID: 0
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 167622/350000 (47.89 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10978/46095 (23.82%)
# 	DeathPerturbation(voronoi): 10974/49109 (22.35%)
# 	NoisePerturbation(rayleigh): 43635/51068 (85.44%)
# 	ParamPerturbation(voronoi.discretization): 24422/51056 (47.83%)
# 	ParamPerturbation(voronoi.vs): 77613/152672 (50.84%)
# Chain ID: 1
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 165550/350000 (47.30 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10883/47152 (23.08%)
# 	DeathPerturbation(voronoi): 10879/47770 (22.77%)
# 	NoisePerturbation(rayleigh): 43759/51096 (85.64%)
# 	ParamPerturbation(voronoi.discretization): 25011/51067 (48.98%)
# 	ParamPerturbation(voronoi.vs): 75018/152915 (49.06%)
# Chain ID: 2
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 167428/350000 (47.84 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 11030/46415 (23.76%)
# 	DeathPerturbation(voronoi): 11024/49070 (22.47%)
# 	NoisePerturbation(rayleigh): 43112/50399 (85.54%)
# 	ParamPerturbation(voronoi.discretization): 24379/50757 (48.03%)
# 	ParamPerturbation(voronoi.vs): 77883/153359 (50.78%)
# Chain ID: 3
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 166413/350000 (47.55 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10941/46394 (23.58%)
# 	DeathPerturbation(voronoi): 10938/48352 (22.62%)
# 	NoisePerturbation(rayleigh): 43476/50965 (85.31%)
# 	ParamPerturbation(voronoi.discretization): 24701/51187 (48.26%)
# 	ParamPerturbation(voronoi.vs): 76357/153102 (49.87%)
# Chain ID: 4
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 165211/350000 (47.20 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10927/47041 (23.23%)
# 	DeathPerturbation(voronoi): 10923/48274 (22.63%)
# 	NoisePerturbation(rayleigh): 43393/50722 (85.55%)
# 	ParamPerturbation(voronoi.discretization): 24233/50593 (47.90%)
# 	ParamPerturbation(voronoi.vs): 75735/153370 (49.38%)
# Chain ID: 5
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 162220/350000 (46.35 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10571/47415 (22.29%)
# 	DeathPerturbation(voronoi): 10564/47146 (22.41%)
# 	NoisePerturbation(rayleigh): 43626/50980 (85.57%)
# 	ParamPerturbation(voronoi.discretization): 24468/51217 (47.77%)
# 	ParamPerturbation(voronoi.vs): 72991/153242 (47.63%)
# Chain ID: 6
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 163854/350000 (46.82 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10748/47281 (22.73%)
# 	DeathPerturbation(voronoi): 10745/48502 (22.15%)
# 	NoisePerturbation(rayleigh): 43713/51020 (85.68%)
# 	ParamPerturbation(voronoi.discretization): 24553/50806 (48.33%)
# 	ParamPerturbation(voronoi.vs): 74095/152391 (48.62%)
# Chain ID: 7
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 162797/350000 (46.51 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10969/47816 (22.94%)
# 	DeathPerturbation(voronoi): 10968/48595 (22.57%)
# 	NoisePerturbation(rayleigh): 43332/51014 (84.94%)
# 	ParamPerturbation(voronoi.discretization): 24320/50461 (48.20%)
# 	ParamPerturbation(voronoi.vs): 73208/152114 (48.13%)
# Chain ID: 8
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 165072/350000 (47.16 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10869/46982 (23.13%)
# 	DeathPerturbation(voronoi): 10867/48617 (22.35%)
# 	NoisePerturbation(rayleigh): 43634/51169 (85.27%)
# 	ParamPerturbation(voronoi.discretization): 24403/50823 (48.02%)
# 	ParamPerturbation(voronoi.vs): 75299/152409 (49.41%)
# Chain ID: 9
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 163417/350000 (46.69 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10928/47606 (22.96%)
# 	DeathPerturbation(voronoi): 10922/48067 (22.72%)
# 	NoisePerturbation(rayleigh): 43227/50750 (85.18%)
# 	ParamPerturbation(voronoi.discretization): 24404/50917 (47.93%)
# 	ParamPerturbation(voronoi.vs): 73936/152660 (48.43%)
# Chain ID: 10
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 164664/350000 (47.05 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10727/46643 (23.00%)
# 	DeathPerturbation(voronoi): 10717/47070 (22.77%)
# 	NoisePerturbation(rayleigh): 43465/50906 (85.38%)
# 	ParamPerturbation(voronoi.discretization): 24769/51423 (48.17%)
# 	ParamPerturbation(voronoi.vs): 74986/153958 (48.71%)
# Chain ID: 11
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 166553/350000 (47.59 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 11029/46995 (23.47%)
# 	DeathPerturbation(voronoi): 11023/48967 (22.51%)
# 	NoisePerturbation(rayleigh): 43536/50952 (85.45%)
# 	ParamPerturbation(voronoi.discretization): 24619/50789 (48.47%)
# 	ParamPerturbation(voronoi.vs): 76346/152297 (50.13%)
# Chain ID: 12
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 167394/350000 (47.83 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10879/46176 (23.56%)
# 	DeathPerturbation(voronoi): 10875/49063 (22.17%)
# 	NoisePerturbation(rayleigh): 44044/51301 (85.85%)
# 	ParamPerturbation(voronoi.discretization): 24542/50974 (48.15%)
# 	ParamPerturbation(voronoi.vs): 77054/152486 (50.53%)
# Chain ID: 13
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 167423/350000 (47.84 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10860/46064 (23.58%)
# 	DeathPerturbation(voronoi): 10857/48337 (22.46%)
# 	NoisePerturbation(rayleigh): 43600/50915 (85.63%)
# 	ParamPerturbation(voronoi.discretization): 24784/50819 (48.77%)
# 	ParamPerturbation(voronoi.vs): 77322/153865 (50.25%)
# Chain ID: 14
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 165066/350000 (47.16 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 11011/47255 (23.30%)
# 	DeathPerturbation(voronoi): 11008/48542 (22.68%)
# 	NoisePerturbation(rayleigh): 43446/50773 (85.57%)
# 	ParamPerturbation(voronoi.discretization): 24915/50734 (49.11%)
# 	ParamPerturbation(voronoi.vs): 74686/152696 (48.91%)
# Chain ID: 15
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 161554/350000 (46.16 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10620/47928 (22.16%)
# 	DeathPerturbation(voronoi): 10618/47349 (22.42%)
# 	NoisePerturbation(rayleigh): 43565/51024 (85.38%)
# 	ParamPerturbation(voronoi.discretization): 24029/50610 (47.48%)
# 	ParamPerturbation(voronoi.vs): 72722/153089 (47.50%)
# Chain ID: 16
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 165325/350000 (47.24 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10605/46658 (22.73%)
# 	DeathPerturbation(voronoi): 10598/48639 (21.79%)
# 	NoisePerturbation(rayleigh): 43556/50800 (85.74%)
# 	ParamPerturbation(voronoi.discretization): 24134/50902 (47.41%)
# 	ParamPerturbation(voronoi.vs): 76432/153001 (49.96%)
# Chain ID: 17
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 163355/350000 (46.67 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10841/47512 (22.82%)
# 	DeathPerturbation(voronoi): 10833/48217 (22.47%)
# 	NoisePerturbation(rayleigh): 43860/51242 (85.59%)
# 	ParamPerturbation(voronoi.discretization): 24582/50868 (48.33%)
# 	ParamPerturbation(voronoi.vs): 73239/152161 (48.13%)
# Chain ID: 18
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 165201/350000 (47.20 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 11006/47221 (23.31%)
# 	DeathPerturbation(voronoi): 11002/48708 (22.59%)
# 	NoisePerturbation(rayleigh): 43550/50929 (85.51%)
# 	ParamPerturbation(voronoi.discretization): 24380/50566 (48.21%)
# 	ParamPerturbation(voronoi.vs): 75263/152576 (49.33%)
# Chain ID: 19
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 167534/350000 (47.87 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10989/46546 (23.61%)
# 	DeathPerturbation(voronoi): 10978/48064 (22.84%)
# 	NoisePerturbation(rayleigh): 43502/50675 (85.85%)
# 	ParamPerturbation(voronoi.discretization): 24845/51009 (48.71%)
# 	ParamPerturbation(voronoi.vs): 77220/153706 (50.24%)

# %%
results = inversion.get_results(concatenate_chains=True)

sampled_voronoi_nuclei = results['voronoi.discretization']
sampled_thickness = [Voronoi1D.compute_cell_extents(n) for n in sampled_voronoi_nuclei]
sampled_vs = results['voronoi.vs']
interp_depths = np.linspace(0, 160, 160)
statistics_vs = Voronoi1D.get_tessellation_statistics(
    sampled_thickness, sampled_vs, interp_depths, input_type='extents'
    )

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(6, 8), gridspec_kw={'width_ratios': [2.5, 1]})
ax1, cbar = Voronoi1D.plot_tessellation_density(sampled_thickness, 
                                                sampled_vs, 
                                                input_type='extents', 
                                                ax=ax1, 
                                                cmap='binary', 
                                                vmin=0, 
                                                vmax=2000)
Voronoi1D.plot_tessellation(THICKNESS, 
                            VS, 
                            ax=ax1, 
                            color='yellow', 
                            lw=3, 
                            label='True Vs',
                            input_type='extents')
ax1.plot(statistics_vs['mean'], interp_depths, 'b', lw=2, label='Vs Ensemble Mean')
ax1.plot(statistics_vs['median'], interp_depths, 'r', lw=2, label='Vs Ensemble Median')
ax1.set_xlabel("Vs [km/s]")
ax1.set_ylabel("Depth [km]")
ax1.legend()

Voronoi1D.plot_interface_hist(sampled_thickness, input_type='extents', bins=75, ec='w', ax=ax2)
ax2.tick_params(labelleft=False)
ax2.set_ylabel('')
ax2.set_ylim(*ax1.get_ylim())
plt.tight_layout()
plt.show()

# %%
d_pred = np.array(results['rayleigh.dpred'])
percentiles = np.percentile(d_pred, (10, 90), axis=0)

# Predicted dispersion curves
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 6))
ax1.plot(PERIODS, phase_vel, 'r--', label='Rayleigh (true Vs)', lw=0.5)
ax1.plot(PERIODS, d_obs, 'ro', label='Observations')
ax1.fill_between(PERIODS, percentiles[0], percentiles[1], color='r', alpha=0.2, label='Inferred Data (10th-90th percentiles)', zorder=100)
ax1.set_xlabel('Period [s]')
ax1.set_ylabel('Phase velocity [km/s]')
ax1.grid()
ax1.legend()

# Histogram of inferred data noise
ax2.axvline(x=RAYLEIGH_STD, color='r', lw=3, alpha=0.3, label='True data noise')
pdf, bins, _ = ax2.hist(results['rayleigh.std'], density=True, bins=20, ec='w', zorder=100, label='Posterior')
ax2.fill_between([target.std_min, target.std_max], 1 / (target.std_max - target.std_min), alpha=0.2, label='Prior')
ax2.set_xlabel('Noise standard deviation')
ax2.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
ax2.legend(framealpha=0.9)
plt.tight_layout()
plt.show()

# %%
def get_subplot_layout(n_subplots):
    rows = int(np.sqrt(n_subplots))
    cols = int(np.ceil(n_subplots / rows))
    return rows, cols

rows, cols = get_subplot_layout(len(inversion.chains))
fig, axes = plt.subplots(rows, cols, figsize=(15, 15))
for ipanel, (ax, chain) in enumerate(zip(np.ravel(axes), inversion.chains)):
    saved_states = chain.saved_states
    saved_nuclei = saved_states["voronoi.discretization"]
    saved_vs = saved_states['voronoi.vs']
    
    Voronoi1D.plot_tessellations(saved_nuclei,
                                 saved_vs, 
                                 ax=ax, 
                                 linewidth=0.1, 
                                 color="k", 
                                 bounds=(0, 150))
    Voronoi1D.plot_tessellation(THICKNESS, 
                                VS, 
                                color='yellow', 
                                lw=2, 
                                ax=ax,
                                input_type='extents')
    Voronoi1D.plot_tessellation_statistics(
        saved_nuclei, saved_vs, interp_depths, ax=ax
    )
    
    ax.set_title(f'Chain {chain.id}')
    ax.tick_params(direction='in', labelleft=False, labelbottom=False)
    ax.set_xlabel('')
    ax.set_ylabel('')
    
    if not ipanel % cols:
        ax.set_ylabel('Depth [km]')
        ax.tick_params(labelleft=True)
    if ipanel >= (rows-1) * cols:
        ax.set_xlabel('Vs [km/s]')
        ax.tick_params(labelbottom=True)
    
plt.tight_layout()
plt.show()
