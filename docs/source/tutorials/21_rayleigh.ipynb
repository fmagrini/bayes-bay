# %% [markdown]
# (rayleigh)=
# # Part I: Rayleigh

# %%
import bayesbay as bb
from bayesbay.discretization import Voronoi1D
import numpy as np
import matplotlib.pyplot as plt
from disba import PhaseDispersion
np.random.seed(30)

# %%
THICKNESS = np.array([10, 10, 15, 20, 20, 20, 20, 20, 0])
VS = np.array([3.38, 3.44, 3.66, 4.25, 4.35, 4.32, 4.315, 4.38, 4.5])
VP_VS = 1.77
VP = VS * VP_VS
RHO = 0.32 * VP + 0.77
PERIODS = np.geomspace(3, 80, 20)
RAYLEIGH_STD = 0.02

# %%
def initialize_vs(param, positions=None):
    vmin, vmax = param.get_vmin_vmax(positions)
    sorted_vals = np.sort(np.random.uniform(vmin, vmax, positions.size))
    return sorted_vals

vs = bb.prior.UniformPrior(name="vs", 
                                    vmin=[2.2, 2.8, 3.3, 4], 
                                    vmax=[3.9, 4.6, 4.8, 5], 
                                    position=[0, 20, 60, 150],
                                    perturb_std=0.15)
vs.set_custom_initialize(initialize_vs)

# %%
pd = PhaseDispersion(THICKNESS, VP, VS, RHO)
phase_vel = pd(PERIODS, mode=0, wave="rayleigh").velocity
d_obs = phase_vel + np.random.normal(0, RAYLEIGH_STD, phase_vel.size)

# %%
# For plotting the prior
depth_prior = np.linspace(0, 200)
vmin_prior, vmax_prior = vs.get_vmin_vmax(depth_prior)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4), gridspec_kw={'width_ratios': [1, 2.5]})
ax1.fill_betweenx(depth_prior, vmin_prior, vmax_prior, alpha=0.2, label='Prior')
Voronoi1D.plot_depth_profile(THICKNESS, VS, label='True Vs', ax=ax1, color='k', lw=2)
ax1.set_xlabel('Vs [km/s]')
ax1.set_ylabel('Depth [km]')
ax1.set_ylim(np.cumsum(THICKNESS)[-1] + max(THICKNESS), 0)
ax1.grid()
ax1.legend()

ax2.plot(PERIODS, phase_vel, 'r--', label='Rayleigh (true Vs)', lw=0.5)
ax2.plot(PERIODS, d_obs, 'ro', label='Rayleigh obs.')
ax2.set_xlabel('Period [s]')
ax2.set_ylabel('Phase velocity [km/s]')
ax2.grid()
ax2.legend()

plt.tight_layout(w_pad=2)
plt.show()

# %%
voronoi = Voronoi1D(
    name="voronoi", 
    vmin=0,
    vmax=150,
    perturb_std=10,
    n_dimensions=None, 
    n_dimensions_min=4,
    n_dimensions_max=15,
    parameters=[vs], 
    birth_from='neighbour'
)
parameterization = bb.parameterization.Parameterization(voronoi)

# %%
print(parameterization.perturbation_functions)
print(parameterization.perturbation_weights)
# Out:
# [ParamPerturbation(voronoi.vs), BirthPerturbation(voronoi), DeathPerturbation(voronoi), ParamPerturbation(voronoi.discretization)]
# [3, 1, 1, 1]

# %%
def forward_sw(state):
    voronoi = state["voronoi"]
    voronoi_sites = voronoi["discretization"]
    thickness = Voronoi1D.compute_cell_extents(voronoi_sites)
    vs = voronoi["vs"]
    vp = vs * VP_VS
    rho = 0.32 * vp + 0.77
    pd = PhaseDispersion(thickness, vp, vs, rho)
    d_pred = pd(PERIODS, mode=0, wave="rayleigh").velocity
    return d_pred

# %%
target = bb.Target("rayleigh", 
                   d_obs, 
                   std_min=0.001, 
                   std_max=0.1, 
                   std_perturb_std=0.002)

# %%
log_likelihood = bb.LogLikelihood(targets=target, fwd_functions=forward_sw)

inversion = bb.BayesianInversion(
    parameterization=parameterization, 
    log_likelihood=log_likelihood,
    n_chains=20
)

# %%
inversion.set_perturbation_funcs(inversion.perturbation_funcs, [3, 1, 1, 1, 1])

# %%
inversion.run(
    sampler=None, 
    n_iterations=300_000, 
    burnin_iterations=75_000, 
    save_every=200,
    print_every=10_000,
    verbose=True
)
# Out:
# Chain ID: 14
# TEMPERATURE: 1
# EXPLORED MODELS: 10000
# ACCEPTANCE RATE: 3071/10000 (30.71 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 192/1489 (12.89%)
# 	DeathPerturbation(voronoi): 181/1190 (15.21%)
# 	NoisePerturbation(rayleigh): 942/1405 (67.05%)
# 	ParamPerturbation(voronoi.discretization): 562/1423 (39.49%)
# 	ParamPerturbation(voronoi.vs): 1194/4493 (26.57%)
# Chain ID: 4
# TEMPERATURE: 1
# EXPLORED MODELS: 10000
# ACCEPTANCE RATE: 3364/10000 (33.64 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 201/1412 (14.24%)
# 	DeathPerturbation(voronoi): 200/1439 (13.90%)
# 	NoisePerturbation(rayleigh): 998/1446 (69.02%)
# 	ParamPerturbation(voronoi.discretization): 601/1485 (40.47%)
# 	ParamPerturbation(voronoi.vs): 1364/4218 (32.34%)
# Chain ID: 15
# TEMPERATURE: 1
# EXPLORED MODELS: 10000
# ACCEPTANCE RATE: 3538/10000 (35.38 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 219/1442 (15.19%)
# 	DeathPerturbation(voronoi): 212/1469 (14.43%)
# 	NoisePerturbation(rayleigh): 998/1456 (68.54%)
# 	ParamPerturbation(voronoi.discretization): 574/1423 (40.34%)
# 	ParamPerturbation(voronoi.vs): 1535/4210 (36.46%)
# Chain ID: 7
# TEMPERATURE: 1
# EXPLORED MODELS: 10000
# ACCEPTANCE RATE: 3946/10000 (39.46 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 267/1485 (17.98%)
# 	DeathPerturbation(voronoi): 262/1325 (19.77%)
# 	NoisePerturbation(rayleigh): 1031/1454 (70.91%)
# 	ParamPerturbation(voronoi.discretization): 660/1446 (45.64%)
# 	ParamPerturbation(voronoi.vs): 1726/4290 (40.23%)
# Chain ID: 0
# TEMPERATURE: 1
# EXPLORED MODELS: 10000
# ACCEPTANCE RATE: 3845/10000 (38.45 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 248/1329 (18.66%)
# 	DeathPerturbation(voronoi): 238/1414 (16.83%)
# 	NoisePerturbation(rayleigh): 1007/1444 (69.74%)Chain ID: 18
# TEMPERATURE: 1
# EXPLORED MODELS: 10000
# ACCEPTANCE RATE: 3937/10000 (39.37 %)
# Chain ID: 12
# TEMPERATURE: 1
# EXPLORED MODELS: 10000
# ACCEPTANCE RATE: 3821/10000 (38.21 %)	ParamPerturbation(voronoi.discretization): 598/1473 (40.60%)
#
# PARTIAL ACCEPTANCE RATES:
#
# Chain ID: 17
# TEMPERATURE: 1
# EXPLORED MODELS: 10000
# ACCEPTANCE RATE: 3730/10000 (37.30 %)PARTIAL ACCEPTANCE RATES:
# PARTIAL ACCEPTANCE RATES:	BirthPerturbation(voronoi): 287/1437 (19.97%)
#
# 	BirthPerturbation(voronoi): 252/1340 (18.81%)
# 	BirthPerturbation(voronoi): 296/1385 (21.37%)	DeathPerturbation(voronoi): 246/1377 (17.86%)
# 	ParamPerturbation(voronoi.vs): 1754/4340 (40.41%)	DeathPerturbation(voronoi): 285/1428 (19.96%)
# 	DeathPerturbation(voronoi): 294/1511 (19.46%)
#
#
#
# 	NoisePerturbation(rayleigh): 1005/1430 (70.28%)	NoisePerturbation(rayleigh): 935/1334 (70.09%)	NoisePerturbation(rayleigh): 1042/1482 (70.31%)Chain ID: 10
# TEMPERATURE: 1
# EXPLORED MODELS: 10000
# ACCEPTANCE RATE: 3763/10000 (37.63 %)
# 	ParamPerturbation(voronoi.discretization): 526/1477 (35.61%)
#
#
# 	ParamPerturbation(voronoi.discretization): 642/1451 (44.25%)
# PARTIAL ACCEPTANCE RATES:	ParamPerturbation(voronoi.vs): 1770/4319 (40.98%)
#
# 	BirthPerturbation(voronoi): 248/1244 (19.94%)
# Chain ID: 16
# TEMPERATURE: 1
# EXPLORED MODELS: 10000
# ACCEPTANCE RATE: 4070/10000 (40.70 %)
# 	ParamPerturbation(voronoi.discretization): 524/1385 (37.83%)
#
# PARTIAL ACCEPTANCE RATES:	DeathPerturbation(voronoi): 243/1355 (17.93%)
# 	NoisePerturbation(rayleigh): 1040/1481 (70.22%)
# 	BirthPerturbation(voronoi): 275/1324 (20.77%)	ParamPerturbation(voronoi.vs): 1664/4324 (38.48%)
# 	ParamPerturbation(voronoi.vs): 1720/4320 (39.81%)
#
#
# 	ParamPerturbation(voronoi.discretization): 617/1431 (43.12%)	DeathPerturbation(voronoi): 265/1461 (18.14%)
# 	NoisePerturbation(rayleigh): 973/1410 (69.01%)
#
# 	ParamPerturbation(voronoi.vs): 1922/4489 (42.82%)Chain ID: 1
# TEMPERATURE: 1
# EXPLORED MODELS: 10000
# ACCEPTANCE RATE: 3866/10000 (38.66 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 248/1354 (18.32%)
#
# 	ParamPerturbation(voronoi.discretization): 516/1400 (36.86%)
# 	DeathPerturbation(voronoi): 246/1449 (16.98%)
# 	NoisePerturbation(rayleigh): 995/1436 (69.29%)
# 	ParamPerturbation(voronoi.discretization): 592/1459 (40.58%)
# 	ParamPerturbation(voronoi.vs): 1785/4302 (41.49%)
# 	ParamPerturbation(voronoi.vs): 1734/4405 (39.36%)
# Chain ID: 3
# TEMPERATURE: 1
# EXPLORED MODELS: 10000
# ACCEPTANCE RATE: 4222/10000 (42.22 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 290/1345 (21.56%)
# 	DeathPerturbation(voronoi): 288/1447 (19.90%)
# 	NoisePerturbation(rayleigh): 1009/1456 (69.30%)
# 	ParamPerturbation(voronoi.discretization): 632/1467 (43.08%)
# 	ParamPerturbation(voronoi.vs): 2003/4285 (46.74%)
# Chain ID: 9
# TEMPERATURE: 1
# EXPLORED MODELS: 10000
# ACCEPTANCE RATE: 3978/10000 (39.78 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 267/1289 (20.71%)
# 	DeathPerturbation(voronoi): 257/1383 (18.58%)
# 	NoisePerturbation(rayleigh): 1036/1485 (69.76%)
# 	ParamPerturbation(voronoi.discretization): 538/1426 (37.73%)
# 	ParamPerturbation(voronoi.vs): 1880/4417 (42.56%)
# Chain ID: 6
# TEMPERATURE: 1
# EXPLORED MODELS: 10000
# ACCEPTANCE RATE: 4298/10000 (42.98 %)Chain ID: 8
# TEMPERATURE: 1
# EXPLORED MODELS: 10000
# ACCEPTANCE RATE: 3904/10000 (39.04 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 314/1368 (22.95%)
#
# PARTIAL ACCEPTANCE RATES:	DeathPerturbation(voronoi): 307/1388 (22.12%)Chain ID: 11
# TEMPERATURE: 1
# EXPLORED MODELS: 10000
# ACCEPTANCE RATE: 4075/10000 (40.75 %)
#
# 	BirthPerturbation(voronoi): 258/1317 (19.59%)PARTIAL ACCEPTANCE RATES:Chain ID: 19
# TEMPERATURE: 1
# EXPLORED MODELS: 10000
# ACCEPTANCE RATE: 4130/10000 (41.30 %)
#
#
# 	NoisePerturbation(rayleigh): 960/1371 (70.02%)	BirthPerturbation(voronoi): 274/1246 (21.99%)
# 	DeathPerturbation(voronoi): 268/1444 (18.56%)
# 	NoisePerturbation(rayleigh): 1009/1451 (69.54%)
#
#
# 	DeathPerturbation(voronoi): 249/1463 (17.02%)	ParamPerturbation(voronoi.discretization): 569/1430 (39.79%)
# 	ParamPerturbation(voronoi.vs): 1955/4429 (44.14%)PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 270/1256 (21.50%)
# 	DeathPerturbation(voronoi): 261/1388 (18.80%)	ParamPerturbation(voronoi.discretization): 614/1482 (41.43%)
#
# 	NoisePerturbation(rayleigh): 1001/1403 (71.35%)	ParamPerturbation(voronoi.vs): 2103/4391 (47.89%)
#
# 	ParamPerturbation(voronoi.discretization): 601/1499 (40.09%)
#
# 	NoisePerturbation(rayleigh): 1026/1460 (70.27%)
# 	ParamPerturbation(voronoi.discretization): 523/1414 (36.99%)
# 	ParamPerturbation(voronoi.vs): 1848/4346 (42.52%)
#
# 	ParamPerturbation(voronoi.vs): 1997/4454 (44.84%)
# Chain ID: 2
# TEMPERATURE: 1
# EXPLORED MODELS: 10000
# ACCEPTANCE RATE: 4072/10000 (40.72 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 281/1326 (21.19%)
# 	DeathPerturbation(voronoi): 274/1445 (18.96%)
# 	NoisePerturbation(rayleigh): 948/1411 (67.19%)
# 	ParamPerturbation(voronoi.discretization): 561/1417 (39.59%)
# 	ParamPerturbation(voronoi.vs): 2008/4401 (45.63%)
# Chain ID: 5
# TEMPERATURE: 1
# EXPLORED MODELS: 10000
# ACCEPTANCE RATE: 3900/10000 (39.00 %)
# PARTIAL ACCEPTANCE RATES:Chain ID: 13
# TEMPERATURE: 1
# EXPLORED MODELS: 10000
# ACCEPTANCE RATE: 3739/10000 (37.39 %)
#
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 222/1250 (17.76%)
# 	DeathPerturbation(voronoi): 218/1397 (15.60%)	BirthPerturbation(voronoi): 255/1200 (21.25%)
# 	NoisePerturbation(rayleigh): 1096/1516 (72.30%)
# 	ParamPerturbation(voronoi.discretization): 534/1482 (36.03%)
# 	ParamPerturbation(voronoi.vs): 1669/4355 (38.32%)
#
# 	DeathPerturbation(voronoi): 252/1485 (16.97%)
# 	NoisePerturbation(rayleigh): 1031/1487 (69.33%)
# 	ParamPerturbation(voronoi.discretization): 516/1422 (36.29%)
# 	ParamPerturbation(voronoi.vs): 1846/4406 (41.90%)
# Chain ID: 4
# TEMPERATURE: 1
# EXPLORED MODELS: 20000
# ACCEPTANCE RATE: 6578/20000 (32.89 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 401/2856 (14.04%)
# 	DeathPerturbation(voronoi): 399/2774 (14.38%)
# 	NoisePerturbation(rayleigh): 1973/2845 (69.35%)
# 	ParamPerturbation(voronoi.discretization): 1132/2883 (39.26%)
# 	ParamPerturbation(voronoi.vs): 2673/8642 (30.93%)
# Chain ID: 14
# TEMPERATURE: 1
# EXPLORED MODELS: 20000
# ACCEPTANCE RATE: 7125/20000 (35.62 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 466/2856 (16.32%)
# 	DeathPerturbation(voronoi): 461/2622 (17.58%)
# 	NoisePerturbation(rayleigh): 1990/2897 (68.69%)
# 	ParamPerturbation(voronoi.discretization): 1207/2911 (41.46%)
# 	ParamPerturbation(voronoi.vs): 3001/8714 (34.44%)
# Chain ID: 17
# TEMPERATURE: 1
# EXPLORED MODELS: 20000
# ACCEPTANCE RATE: 7017/20000 (35.09 %)
# Chain ID: 7
# TEMPERATURE: 1
# EXPLORED MODELS: 20000
# ACCEPTANCE RATE: 7821/20000 (39.11 %)PARTIAL ACCEPTANCE RATES:
#
# PARTIAL ACCEPTANCE RATES:	BirthPerturbation(voronoi): 456/2776 (16.43%)
# 	DeathPerturbation(voronoi): 455/2623 (17.35%)
# 	NoisePerturbation(rayleigh): 2070/2963 (69.86%)
# 	ParamPerturbation(voronoi.discretization): 1051/2920 (35.99%)
# 	ParamPerturbation(voronoi.vs): 2985/8718 (34.24%)
#
# 	BirthPerturbation(voronoi): 542/2773 (19.55%)
# 	DeathPerturbation(voronoi): 535/2802 (19.09%)
# 	NoisePerturbation(rayleigh): 2019/2907 (69.45%)
# 	ParamPerturbation(voronoi.discretization): 1157/2848 (40.62%)
# 	ParamPerturbation(voronoi.vs): 3568/8670 (41.15%)
# Chain ID: 12
# TEMPERATURE: 1
# EXPLORED MODELS: 20000
# ACCEPTANCE RATE: 7406/20000 (37.03 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 509/2798 (18.19%)
# 	DeathPerturbation(voronoi): 504/2804 (17.97%)
# 	NoisePerturbation(rayleigh): 1988/2856 (69.61%)
# 	ParamPerturbation(voronoi.discretization): 1059/2816 (37.61%)
# 	ParamPerturbation(voronoi.vs): 3346/8726 (38.35%)
# Chain ID: 8
# TEMPERATURE: 1
# EXPLORED MODELS: 20000
# ACCEPTANCE RATE: 7218/20000 (36.09 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 490/2772 (17.68%)
# 	DeathPerturbation(voronoi): 489/2636 (18.55%)
# 	NoisePerturbation(rayleigh): 2021/2869 (70.44%)
# 	ParamPerturbation(voronoi.discretization): 1115/2858 (39.01%)
# 	ParamPerturbation(voronoi.vs): 3103/8865 (35.00%)
# Chain ID: 0
# TEMPERATURE: 1
# EXPLORED MODELS: 20000
# ACCEPTANCE RATE: 7255/20000 (36.27 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 439/2757 (15.92%)
# 	DeathPerturbation(voronoi): 436/2513 (17.35%)
# 	NoisePerturbation(rayleigh): 2112/2973 (71.04%)
# 	ParamPerturbation(voronoi.discretization): 1102/2980 (36.98%)
# 	ParamPerturbation(voronoi.vs): 3166/8777 (36.07%)
# Chain ID: 15
# TEMPERATURE: 1
# EXPLORED MODELS: 20000
# ACCEPTANCE RATE: 7510/20000 (37.55 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 479/2742 (17.47%)
# 	DeathPerturbation(voronoi): 471/2847 (16.54%)
# 	NoisePerturbation(rayleigh): 1979/2920 (67.77%)
# 	ParamPerturbation(voronoi.discretization): 1140/2858 (39.89%)
# 	ParamPerturbation(voronoi.vs): 3441/8633 (39.86%)
# Chain ID: 6
# TEMPERATURE: 1
# EXPLORED MODELS: 20000
# ACCEPTANCE RATE: 8099/20000 (40.49 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 562/2828 (19.87%)
# 	DeathPerturbation(voronoi): 555/2735 (20.29%)
# 	NoisePerturbation(rayleigh): 1961/2813 (69.71%)
# 	ParamPerturbation(voronoi.discretization): 1194/2874 (41.54%)
# 	ParamPerturbation(voronoi.vs): 3827/8750 (43.74%)
# Chain ID: 1
# TEMPERATURE: 1
# EXPLORED MODELS: 20000
# ACCEPTANCE RATE: 7583/20000 (37.91 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 514/2776 (18.52%)
# 	DeathPerturbation(voronoi): 506/2925 (17.30%)
# 	NoisePerturbation(rayleigh): 1968/2854 (68.96%)
# 	ParamPerturbation(voronoi.discretization): 1160/2882 (40.25%)
# 	ParamPerturbation(voronoi.vs): 3435/8563 (40.11%)
# Chain ID: 3
# TEMPERATURE: 1
# EXPLORED MODELS: 20000
# ACCEPTANCE RATE: 8120/20000 (40.60 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 536/2729 (19.64%)
# 	DeathPerturbation(voronoi): 530/2665 (19.89%)
# 	NoisePerturbation(rayleigh): 2069/2954 (70.04%)
# 	ParamPerturbation(voronoi.discretization): 1240/2992 (41.44%)
# 	ParamPerturbation(voronoi.vs): 3745/8660 (43.24%)
# Chain ID: 11
# TEMPERATURE: 1
# EXPLORED MODELS: 20000
# ACCEPTANCE RATE: 7477/20000 (37.39 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 477/2575 (18.52%)
# 	DeathPerturbation(voronoi): 471/2853 (16.51%)
# 	NoisePerturbation(rayleigh): 2043/2938 (69.54%)
# 	ParamPerturbation(voronoi.discretization): 1139/2885 (39.48%)
# 	ParamPerturbation(voronoi.vs): 3347/8749 (38.26%)
# Chain ID: 5
# TEMPERATURE: 1
# EXPLORED MODELS: 20000
# ACCEPTANCE RATE: 7391/20000 (36.95 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 481/2653 (18.13%)
# 	DeathPerturbation(voronoi): 471/2930 (16.08%)
# 	NoisePerturbation(rayleigh): 2013/2894 (69.56%)
# 	ParamPerturbation(voronoi.discretization): 1037/2828 (36.67%)
# 	ParamPerturbation(voronoi.vs): 3389/8695 (38.98%)
# Chain ID: 18
# TEMPERATURE: 1
# EXPLORED MODELS: 20000
# ACCEPTANCE RATE: 8223/20000 (41.12 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 587/2635 (22.28%)
# 	DeathPerturbation(voronoi): 582/2961 (19.66%)
# 	NoisePerturbation(rayleigh): 1885/2717 (69.38%)
# 	ParamPerturbation(voronoi.discretization): 1283/2932 (43.76%)
# 	ParamPerturbation(voronoi.vs): 3886/8755 (44.39%)
# Chain ID: 16
# TEMPERATURE: 1
# EXPLORED MODELS: 20000
# ACCEPTANCE RATE: 8321/20000 (41.60 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 548/2521 (21.74%)
# 	DeathPerturbation(voronoi): 542/2834 (19.12%)
# 	NoisePerturbation(rayleigh): 2064/2990 (69.03%)
# 	ParamPerturbation(voronoi.discretization): 1217/2837 (42.90%)
# 	ParamPerturbation(voronoi.vs): 3950/8818 (44.79%)
# Chain ID: 10
# TEMPERATURE: 1
# EXPLORED MODELS: 20000
# ACCEPTANCE RATE: 7647/20000 (38.23 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 492/2488 (19.77%)
# 	DeathPerturbation(voronoi): 488/2906 (16.79%)
# 	NoisePerturbation(rayleigh): 2024/2922 (69.27%)
# 	ParamPerturbation(voronoi.discretization): 1079/2889 (37.35%)
# 	ParamPerturbation(voronoi.vs): 3564/8795 (40.52%)
# Chain ID: 9
# TEMPERATURE: 1
# EXPLORED MODELS: 20000
# ACCEPTANCE RATE: 8098/20000 (40.49 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 550/2545 (21.61%)
# 	DeathPerturbation(voronoi): 541/2813 (19.23%)
# 	NoisePerturbation(rayleigh): 2020/2939 (68.73%)
# 	ParamPerturbation(voronoi.discretization): 1095/2859 (38.30%)
# 	ParamPerturbation(voronoi.vs): 3892/8844 (44.01%)
# Chain ID: 2
# TEMPERATURE: 1
# EXPLORED MODELS: 20000
# ACCEPTANCE RATE: 8170/20000 (40.85 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 542/2600 (20.85%)
# 	DeathPerturbation(voronoi): 535/2875 (18.61%)
# 	NoisePerturbation(rayleigh): 1937/2868 (67.54%)
# 	ParamPerturbation(voronoi.discretization): 1102/2846 (38.72%)
# 	ParamPerturbation(voronoi.vs): 4054/8811 (46.01%)
# Chain ID: 13
# TEMPERATURE: 1
# EXPLORED MODELS: 20000
# ACCEPTANCE RATE: 7366/20000 (36.83 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 444/2465 (18.01%)
# 	DeathPerturbation(voronoi): 437/2864 (15.26%)
# 	NoisePerturbation(rayleigh): 2121/2986 (71.03%)
# 	ParamPerturbation(voronoi.discretization): 1002/2921 (34.30%)
# 	ParamPerturbation(voronoi.vs): 3362/8764 (38.36%)
# Chain ID: 4
# TEMPERATURE: 1
# EXPLORED MODELS: 30000
# ACCEPTANCE RATE: 10501/30000 (35.00 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 657/4131 (15.90%)
# 	DeathPerturbation(voronoi): 648/4203 (15.42%)
# 	NoisePerturbation(rayleigh): 3010/4363 (68.99%)
# 	ParamPerturbation(voronoi.discretization): 1716/4307 (39.84%)
# 	ParamPerturbation(voronoi.vs): 4470/12996 (34.40%)
# Chain ID: 8
# TEMPERATURE: 1
# EXPLORED MODELS: 30000
# ACCEPTANCE RATE: 10713/30000 (35.71 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 709/4143 (17.11%)
# 	DeathPerturbation(voronoi): 706/3956 (17.85%)Chain ID: 12
# TEMPERATURE: 1
# EXPLORED MODELS: 30000
# ACCEPTANCE RATE: 11259/30000 (37.53 %)
#
# 	NoisePerturbation(rayleigh): 3019/4323 (69.84%)PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 756/4106 (18.41%)
#
# 	ParamPerturbation(voronoi.discretization): 1699/4375 (38.83%)	DeathPerturbation(voronoi): 754/4223 (17.85%)
#
# 	ParamPerturbation(voronoi.vs): 4580/13203 (34.69%)
# 	NoisePerturbation(rayleigh): 2994/4320 (69.31%)Chain ID: 19
# TEMPERATURE: 1
# EXPLORED MODELS: 20000
# ACCEPTANCE RATE: 7999/20000 (40.00 %)
#
# 	ParamPerturbation(voronoi.discretization): 1656/4251 (38.96%)PARTIAL ACCEPTANCE RATES:
#
# 	ParamPerturbation(voronoi.vs): 5099/13100 (38.92%)
# 	BirthPerturbation(voronoi): 464/2162 (21.46%)
# 	DeathPerturbation(voronoi): 458/2870 (15.96%)
# 	NoisePerturbation(rayleigh): 2033/2887 (70.42%)
# 	ParamPerturbation(voronoi.discretization): 1037/3018 (34.36%)
# 	ParamPerturbation(voronoi.vs): 4007/9063 (44.21%)
# Chain ID: 17
# TEMPERATURE: 1
# EXPLORED MODELS: 30000
# ACCEPTANCE RATE: 10656/30000 (35.52 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 708/4151 (17.06%)
# 	DeathPerturbation(voronoi): 705/4028 (17.50%)
# 	NoisePerturbation(rayleigh): 3045/4378 (69.55%)
# 	ParamPerturbation(voronoi.discretization): 1601/4363 (36.69%)
# 	ParamPerturbation(voronoi.vs): 4597/13080 (35.15%)
# Chain ID: 7
# TEMPERATURE: 1
# EXPLORED MODELS: 30000
# ACCEPTANCE RATE: 11531/30000 (38.44 %)
# PARTIAL ACCEPTANCE RATES:
# Chain ID: 1
# TEMPERATURE: 1
# EXPLORED MODELS: 30000
# ACCEPTANCE RATE: 11209/30000 (37.36 %)
# 	BirthPerturbation(voronoi): 759/4032 (18.82%)
# PARTIAL ACCEPTANCE RATES:
# 	DeathPerturbation(voronoi): 749/4244 (17.65%)	BirthPerturbation(voronoi): 765/4149 (18.44%)
#
# 	NoisePerturbation(rayleigh): 2971/4327 (68.66%)
# 	DeathPerturbation(voronoi): 761/4419 (17.22%)	ParamPerturbation(voronoi.discretization): 1711/4307 (39.73%)
# 	ParamPerturbation(voronoi.vs): 5341/13090 (40.80%)
# 	NoisePerturbation(rayleigh): 2856/4206 (67.90%)
#
# 	ParamPerturbation(voronoi.discretization): 1685/4292 (39.26%)
# Chain ID: 14
# TEMPERATURE: 1
# EXPLORED MODELS: 30000
# ACCEPTANCE RATE: 11222/30000 (37.41 %)	ParamPerturbation(voronoi.vs): 5142/12934 (39.76%)
#
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 758/4244 (17.86%)
# 	DeathPerturbation(voronoi): 752/4031 (18.66%)
# 	NoisePerturbation(rayleigh): 2912/4257 (68.40%)
# 	ParamPerturbation(voronoi.discretization): 1825/4378 (41.69%)
# 	ParamPerturbation(voronoi.vs): 4975/13090 (38.01%)
# Chain ID: 6
# TEMPERATURE: 1
# EXPLORED MODELS: 30000
# ACCEPTANCE RATE: 11986/30000 (39.95 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 777/4264 (18.22%)
# 	DeathPerturbation(voronoi): 773/4180 (18.49%)
# 	NoisePerturbation(rayleigh): 2936/4237 (69.29%)Chain ID: 15
# TEMPERATURE: 1
# EXPLORED MODELS: 30000
# ACCEPTANCE RATE: 11296/30000 (37.65 %)
# 	ParamPerturbation(voronoi.discretization): 1742/4281 (40.69%)
#
# PARTIAL ACCEPTANCE RATES:	ParamPerturbation(voronoi.vs): 5758/13038 (44.16%)
#
# 	BirthPerturbation(voronoi): 727/4033 (18.03%)
# 	DeathPerturbation(voronoi): 721/4243 (16.99%)
# 	NoisePerturbation(rayleigh): 2990/4391 (68.09%)
# 	ParamPerturbation(voronoi.discretization): 1698/4313 (39.37%)
# 	ParamPerturbation(voronoi.vs): 5160/13020 (39.63%)
# Chain ID: 11
# TEMPERATURE: 1
# EXPLORED MODELS: 30000
# ACCEPTANCE RATE: 11033/30000 (36.78 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 721/4077 (17.68%)
# 	DeathPerturbation(voronoi): 710/4038 (17.58%)
# 	NoisePerturbation(rayleigh): 3069/4411 (69.58%)
# 	ParamPerturbation(voronoi.discretization): 1675/4380 (38.24%)
# 	ParamPerturbation(voronoi.vs): 4858/13094 (37.10%)
# Chain ID: 10
# TEMPERATURE: 1
# EXPLORED MODELS: 30000
# ACCEPTANCE RATE: 10755/30000 (35.85 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 686/4008 (17.12%)
# 	DeathPerturbation(voronoi): 686/3943 (17.40%)
# 	NoisePerturbation(rayleigh): 3109/4464 (69.65%)
# 	ParamPerturbation(voronoi.discretization): 1577/4315 (36.55%)
# 	ParamPerturbation(voronoi.vs): 4697/13270 (35.40%)
# Chain ID: 9
# TEMPERATURE: 1
# EXPLORED MODELS: 30000
# ACCEPTANCE RATE: 11663/30000 (38.88 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 762/3837 (19.86%)
# 	DeathPerturbation(voronoi): 758/4243 (17.86%)
# 	NoisePerturbation(rayleigh): 3061/4431 (69.08%)
# 	ParamPerturbation(voronoi.discretization): 1657/4304 (38.50%)
# 	ParamPerturbation(voronoi.vs): 5425/13185 (41.15%)
# Chain ID: 3
# TEMPERATURE: 1
# EXPLORED MODELS: 30000
# ACCEPTANCE RATE: 12150/30000 (40.50 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 811/4119 (19.69%)Chain ID: 5
# TEMPERATURE: 1
# EXPLORED MODELS: 30000
# ACCEPTANCE RATE: 11190/30000 (37.30 %)
#
# 	DeathPerturbation(voronoi): 808/4072 (19.84%)PARTIAL ACCEPTANCE RATES:
#
# 	BirthPerturbation(voronoi): 703/3921 (17.93%)	NoisePerturbation(rayleigh): 3055/4406 (69.34%)
#
# 	DeathPerturbation(voronoi): 701/4383 (15.99%)	ParamPerturbation(voronoi.discretization): 1822/4424 (41.18%)
# 	NoisePerturbation(rayleigh): 2988/4339 (68.86%)
# 	ParamPerturbation(voronoi.discretization): 1647/4219 (39.04%)
# 	ParamPerturbation(voronoi.vs): 5151/13138 (39.21%)
#
# 	ParamPerturbation(voronoi.vs): 5654/12979 (43.56%)
# Chain ID: 0
# TEMPERATURE: 1
# EXPLORED MODELS: 30000
# ACCEPTANCE RATE: 11348/30000 (37.83 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 678/3929 (17.26%)
# 	DeathPerturbation(voronoi): 667/3943 (16.92%)
# 	NoisePerturbation(rayleigh): 3137/4455 (70.42%)
# 	ParamPerturbation(voronoi.discretization): 1706/4479 (38.09%)
# 	ParamPerturbation(voronoi.vs): 5160/13194 (39.11%)
# Chain ID: 13
# TEMPERATURE: 1
# EXPLORED MODELS: 30000
# ACCEPTANCE RATE: 10482/30000 (34.94 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 639/3914 (16.33%)
# 	DeathPerturbation(voronoi): 637/4086 (15.59%)
# 	NoisePerturbation(rayleigh): 3124/4427 (70.57%)
# 	ParamPerturbation(voronoi.discretization): 1555/4384 (35.47%)
# 	ParamPerturbation(voronoi.vs): 4527/13189 (34.32%)
# Chain ID: 2
# TEMPERATURE: 1
# EXPLORED MODELS: 30000
# ACCEPTANCE RATE: 11657/30000 (38.86 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 753/3981 (18.91%)
# 	DeathPerturbation(voronoi): 749/4092 (18.30%)
# 	NoisePerturbation(rayleigh): 2936/4311 (68.10%)
# 	ParamPerturbation(voronoi.discretization): 1668/4315 (38.66%)
# 	ParamPerturbation(voronoi.vs): 5551/13301 (41.73%)
# Chain ID: 18
# TEMPERATURE: 1
# EXPLORED MODELS: 30000
# ACCEPTANCE RATE: 12257/30000 (40.86 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 876/3961 (22.12%)
# 	DeathPerturbation(voronoi): 869/4386 (19.81%)
# 	NoisePerturbation(rayleigh): 2859/4146 (68.96%)
# 	ParamPerturbation(voronoi.discretization): 1873/4422 (42.36%)
# 	ParamPerturbation(voronoi.vs): 5780/13085 (44.17%)
# Chain ID: 16
# TEMPERATURE: 1
# EXPLORED MODELS: 30000
# ACCEPTANCE RATE: 11871/30000 (39.57 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 746/3867 (19.29%)
# 	DeathPerturbation(voronoi): 742/4259 (17.42%)
# 	NoisePerturbation(rayleigh): 3014/4421 (68.17%)
# 	ParamPerturbation(voronoi.discretization): 1672/4326 (38.65%)
# 	ParamPerturbation(voronoi.vs): 5697/13127 (43.40%)
# Chain ID: 12
# TEMPERATURE: 1
# EXPLORED MODELS: 40000
# ACCEPTANCE RATE: 14597/40000 (36.49 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 957/5536 (17.29%)
# 	DeathPerturbation(voronoi): 956/5514 (17.34%)
# 	NoisePerturbation(rayleigh): 4047/5833 (69.38%)
# 	ParamPerturbation(voronoi.discretization): 2161/5658 (38.19%)
# 	ParamPerturbation(voronoi.vs): 6476/17459 (37.09%)
# Chain ID: 8
# TEMPERATURE: 1
# EXPLORED MODELS: 40000
# ACCEPTANCE RATE: 14287/40000 (35.72 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 970/5548 (17.48%)
# 	DeathPerturbation(voronoi): 962/5357 (17.96%)
# 	NoisePerturbation(rayleigh): 4009/5767 (69.52%)
# 	ParamPerturbation(voronoi.discretization): 2255/5789 (38.95%)
# 	ParamPerturbation(voronoi.vs): 6091/17539 (34.73%)
# Chain ID: 4
# TEMPERATURE: 1
# EXPLORED MODELS: 40000
# ACCEPTANCE RATE: 14496/40000 (36.24 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 936/5458 (17.15%)
# 	DeathPerturbation(voronoi): 931/5660 (16.45%)
# 	NoisePerturbation(rayleigh): 3985/5803 (68.67%)
# 	ParamPerturbation(voronoi.discretization): 2278/5740 (39.69%)
# 	ParamPerturbation(voronoi.vs): 6366/17339 (36.71%)
# Chain ID: 15
# TEMPERATURE: 1
# EXPLORED MODELS: 40000
# ACCEPTANCE RATE: 14898/40000 (37.24 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 942/5372 (17.54%)
# 	DeathPerturbation(voronoi): 941/5562 (16.92%)
# 	NoisePerturbation(rayleigh): 3981/5846 (68.10%)
# 	ParamPerturbation(voronoi.discretization): 2296/5796 (39.61%)
# 	ParamPerturbation(voronoi.vs): 6738/17424 (38.67%)
# Chain ID: 7
# TEMPERATURE: 1
# EXPLORED MODELS: 40000
# ACCEPTANCE RATE: 14989/40000 (37.47 %)Chain ID: 17
# TEMPERATURE: 1
# EXPLORED MODELS: 40000
# ACCEPTANCE RATE: 14675/40000 (36.69 %)
#
# PARTIAL ACCEPTANCE RATES:PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 996/5393 (18.47%)
# 	DeathPerturbation(voronoi): 986/5653 (17.44%)
# 	NoisePerturbation(rayleigh): 3921/5759 (68.08%)
# 	ParamPerturbation(voronoi.discretization): 2251/5749 (39.15%)
# 	ParamPerturbation(voronoi.vs): 6835/17446 (39.18%)
#
# 	BirthPerturbation(voronoi): 956/5486 (17.43%)
# 	DeathPerturbation(voronoi): 952/5431 (17.53%)
# 	NoisePerturbation(rayleigh): 4048/5853 (69.16%)
# 	ParamPerturbation(voronoi.discretization): 2170/5802 (37.40%)
# 	ParamPerturbation(voronoi.vs): 6549/17428 (37.58%)
# Chain ID: 14
# TEMPERATURE: 1
# EXPLORED MODELS: 40000
# ACCEPTANCE RATE: 14960/40000 (37.40 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 992/5609 (17.69%)
# 	DeathPerturbation(voronoi): 991/5512 (17.98%)
# 	NoisePerturbation(rayleigh): 3879/5648 (68.68%)
# 	ParamPerturbation(voronoi.discretization): 2399/5801 (41.35%)
# 	ParamPerturbation(voronoi.vs): 6699/17430 (38.43%)
# Chain ID: 3
# TEMPERATURE: 1
# EXPLORED MODELS: 40000
# ACCEPTANCE RATE: 15545/40000 (38.86 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1040/5459 (19.05%)
# 	DeathPerturbation(voronoi): 1031/5531 (18.64%)
# 	NoisePerturbation(rayleigh): 4013/5812 (69.05%)
# 	ParamPerturbation(voronoi.discretization): 2339/5897 (39.66%)
# 	ParamPerturbation(voronoi.vs): 7122/17301 (41.17%)
# Chain ID: 11
# TEMPERATURE: 1
# EXPLORED MODELS: 40000
# ACCEPTANCE RATE: 14554/40000 (36.38 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 930/5397 (17.23%)
# 	DeathPerturbation(voronoi): 924/5262 (17.56%)
# 	NoisePerturbation(rayleigh): 4128/5924 (69.68%)
# 	ParamPerturbation(voronoi.discretization): 2280/5885 (38.74%)
# 	ParamPerturbation(voronoi.vs): 6292/17532 (35.89%)
# Chain ID: 10
# TEMPERATURE: 1
# EXPLORED MODELS: 40000
# ACCEPTANCE RATE: 14358/40000 (35.89 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 901/5427 (16.60%)
# 	DeathPerturbation(voronoi): 892/5256 (16.97%)
# 	NoisePerturbation(rayleigh): 4102/5940 (69.06%)
# 	ParamPerturbation(voronoi.discretization): 2095/5740 (36.50%)
# 	ParamPerturbation(voronoi.vs): 6368/17637 (36.11%)
# Chain ID: 1
# TEMPERATURE: 1
# EXPLORED MODELS: 40000
# ACCEPTANCE RATE: 15252/40000 (38.13 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 993/5331 (18.63%)
# 	DeathPerturbation(voronoi): 987/5819 (16.96%)
# 	NoisePerturbation(rayleigh): 3903/5731 (68.10%)
# 	ParamPerturbation(voronoi.discretization): 2236/5721 (39.08%)
# 	ParamPerturbation(voronoi.vs): 7133/17398 (41.00%)
# Chain ID: 6
# TEMPERATURE: 1
# EXPLORED MODELS: 40000
# ACCEPTANCE RATE: 16007/40000 (40.02 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1019/5659 (18.01%)
# 	DeathPerturbation(voronoi): 1014/5552 (18.26%)
# 	NoisePerturbation(rayleigh): 3903/5652 (69.06%)
# 	ParamPerturbation(voronoi.discretization): 2315/5747 (40.28%)
# 	ParamPerturbation(voronoi.vs): 7756/17390 (44.60%)
# Chain ID: 13
# TEMPERATURE: 1
# EXPLORED MODELS: 40000
# ACCEPTANCE RATE: 14252/40000 (35.63 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 885/5262 (16.82%)
# 	DeathPerturbation(voronoi): 876/5562 (15.75%)
# 	NoisePerturbation(rayleigh): 4089/5837 (70.05%)
# 	ParamPerturbation(voronoi.discretization): 2164/5840 (37.05%)
# 	ParamPerturbation(voronoi.vs): 6238/17499 (35.65%)
# Chain ID: 19
# TEMPERATURE: 1
# EXPLORED MODELS: 30000
# ACCEPTANCE RATE: 11760/30000 (39.20 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 707/3457 (20.45%)
# 	DeathPerturbation(voronoi): 703/4318 (16.28%)
# 	NoisePerturbation(rayleigh): 3037/4327 (70.19%)
# 	ParamPerturbation(voronoi.discretization): 1608/4510 (35.65%)
# 	ParamPerturbation(voronoi.vs): 5705/13388 (42.61%)
# Chain ID: 5
# TEMPERATURE: 1
# EXPLORED MODELS: 40000
# ACCEPTANCE RATE: 14524/40000 (36.31 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 935/5350 (17.48%)
# 	DeathPerturbation(voronoi): 928/5771 (16.08%)
# 	NoisePerturbation(rayleigh): 3934/5741 (68.52%)
# 	ParamPerturbation(voronoi.discretization): 2176/5680 (38.31%)
# 	ParamPerturbation(voronoi.vs): 6551/17458 (37.52%)
# Chain ID: 9
# TEMPERATURE: 1
# EXPLORED MODELS: 40000
# ACCEPTANCE RATE: 15694/40000 (39.23 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1029/5201 (19.78%)
# 	DeathPerturbation(voronoi): 1026/5675 (18.08%)
# 	NoisePerturbation(rayleigh): 4081/5905 (69.11%)
# 	ParamPerturbation(voronoi.discretization): 2243/5747 (39.03%)
# 	ParamPerturbation(voronoi.vs): 7315/17472 (41.87%)
# Chain ID: 12
# TEMPERATURE: 1
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 17445/50000 (34.89 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1111/6987 (15.90%)
# 	DeathPerturbation(voronoi): 1100/6583 (16.71%)
# 	NoisePerturbation(rayleigh): 5129/7370 (69.59%)
# 	ParamPerturbation(voronoi.discretization): 2614/7152 (36.55%)
# 	ParamPerturbation(voronoi.vs): 7491/21908 (34.19%)
# Chain ID: 2
# TEMPERATURE: 1
# EXPLORED MODELS: 40000
# ACCEPTANCE RATE: 15308/40000 (38.27 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 987/5318 (18.56%)
# 	DeathPerturbation(voronoi): 985/5519 (17.85%)
# 	NoisePerturbation(rayleigh): 3953/5769 (68.52%)
# 	ParamPerturbation(voronoi.discretization): 2217/5774 (38.40%)
# 	ParamPerturbation(voronoi.vs): 7166/17620 (40.67%)
# Chain ID: 0
# TEMPERATURE: 1
# EXPLORED MODELS: 40000
# ACCEPTANCE RATE: 15537/40000 (38.84 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 918/5098 (18.01%)
# 	DeathPerturbation(voronoi): 908/5371 (16.91%)
# 	NoisePerturbation(rayleigh): 4185/5963 (70.18%)
# 	ParamPerturbation(voronoi.discretization): 2309/5965 (38.71%)
# 	ParamPerturbation(voronoi.vs): 7217/17603 (41.00%)
# Chain ID: 16
# TEMPERATURE: 1
# EXPLORED MODELS: 40000
# ACCEPTANCE RATE: 15545/40000 (38.86 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 992/5197 (19.09%)
# 	DeathPerturbation(voronoi): 990/5537 (17.88%)
# 	NoisePerturbation(rayleigh): 4010/5901 (67.95%)
# 	ParamPerturbation(voronoi.discretization): 2231/5795 (38.50%)
# 	ParamPerturbation(voronoi.vs): 7322/17570 (41.67%)
# Chain ID: 15
# TEMPERATURE: 1
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 18742/50000 (37.48 %)Chain ID: 18
# TEMPERATURE: 1
# EXPLORED MODELS: 40000
# ACCEPTANCE RATE: 16205/40000 (40.51 %)
#
# PARTIAL ACCEPTANCE RATES:PARTIAL ACCEPTANCE RATES:
#
# 	BirthPerturbation(voronoi): 1134/5190 (21.85%)	BirthPerturbation(voronoi): 1213/6818 (17.79%)
# 	DeathPerturbation(voronoi): 1130/5910 (19.12%)
# 	NoisePerturbation(rayleigh): 3856/5606 (68.78%)
# 	ParamPerturbation(voronoi.discretization): 2362/5797 (40.75%)
# 	ParamPerturbation(voronoi.vs): 7723/17497 (44.14%)
#
# 	DeathPerturbation(voronoi): 1209/7004 (17.26%)
# 	NoisePerturbation(rayleigh): 4979/7275 (68.44%)
# 	ParamPerturbation(voronoi.discretization): 2939/7235 (40.62%)
# 	ParamPerturbation(voronoi.vs): 8402/21668 (38.78%)
# Chain ID: 7
# TEMPERATURE: 1
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 18906/50000 (37.81 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1230/6713 (18.32%)
# 	DeathPerturbation(voronoi): 1224/7081 (17.29%)
# 	NoisePerturbation(rayleigh): 4918/7192 (68.38%)
# 	ParamPerturbation(voronoi.discretization): 2869/7231 (39.68%)
# 	ParamPerturbation(voronoi.vs): 8665/21783 (39.78%)
# Chain ID: 8
# TEMPERATURE: 1
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 18366/50000 (36.73 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1232/6819 (18.07%)
# 	DeathPerturbation(voronoi): 1226/6712 (18.27%)
# 	NoisePerturbation(rayleigh): 5044/7263 (69.45%)
# 	ParamPerturbation(voronoi.discretization): 2844/7245 (39.25%)
# 	ParamPerturbation(voronoi.vs): 8020/21961 (36.52%)
# Chain ID: 4
# TEMPERATURE: 1
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 18590/50000 (37.18 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1199/6732 (17.81%)
# 	DeathPerturbation(voronoi): 1191/7164 (16.62%)
# 	NoisePerturbation(rayleigh): 4995/7317 (68.27%)
# 	ParamPerturbation(voronoi.discretization): 2811/7180 (39.15%)
# 	ParamPerturbation(voronoi.vs): 8394/21607 (38.85%)
# Chain ID: 6
# TEMPERATURE: 1
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 19649/50000 (39.30 %)Chain ID: 14
# TEMPERATURE: 1
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 18523/50000 (37.05 %)
#
# PARTIAL ACCEPTANCE RATES:
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1254/7050 (17.79%)	BirthPerturbation(voronoi): 1230/7017 (17.53%)
# 	DeathPerturbation(voronoi): 1249/6963 (17.94%)
# 	NoisePerturbation(rayleigh): 4880/7069 (69.03%)
# 	ParamPerturbation(voronoi.discretization): 2920/7242 (40.32%)
# 	ParamPerturbation(voronoi.vs): 9346/21676 (43.12%)
#
# 	DeathPerturbation(voronoi): 1220/7047 (17.31%)
# 	NoisePerturbation(rayleigh): 4850/7088 (68.43%)
# Chain ID: 17
# TEMPERATURE: 1
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 18780/50000 (37.56 %)	ParamPerturbation(voronoi.discretization): 2928/7255 (40.36%)
# 	ParamPerturbation(voronoi.vs): 8295/21593 (38.42%)
#
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1209/6677 (18.11%)
# 	DeathPerturbation(voronoi): 1206/6855 (17.59%)
# 	NoisePerturbation(rayleigh): 5062/7312 (69.23%)
# 	ParamPerturbation(voronoi.discretization): 2785/7346 (37.91%)
# 	ParamPerturbation(voronoi.vs): 8518/21810 (39.06%)
# Chain ID: 1
# TEMPERATURE: 1
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 19049/50000 (38.10 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1221/6562 (18.61%)
# 	DeathPerturbation(voronoi): 1213/7192 (16.87%)
# 	NoisePerturbation(rayleigh): 4849/7145 (67.87%)
# 	ParamPerturbation(voronoi.discretization): 2776/7188 (38.62%)
# 	ParamPerturbation(voronoi.vs): 8990/21913 (41.03%)
# Chain ID: 3
# TEMPERATURE: 1
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 19439/50000 (38.88 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1309/6810 (19.22%)
# 	DeathPerturbation(voronoi): 1309/6935 (18.88%)
# 	NoisePerturbation(rayleigh): 5022/7294 (68.85%)
# Chain ID: 11
# TEMPERATURE: 1
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 18163/50000 (36.33 %)	ParamPerturbation(voronoi.discretization): 2905/7260 (40.01%)
#
# 	ParamPerturbation(voronoi.vs): 8894/21701 (40.98%)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1156/6724 (17.19%)
# 	DeathPerturbation(voronoi): 1147/6724 (17.06%)
# 	NoisePerturbation(rayleigh): 5145/7409 (69.44%)
# 	ParamPerturbation(voronoi.discretization): 2810/7286 (38.57%)
# 	ParamPerturbation(voronoi.vs): 7905/21857 (36.17%)
# Chain ID: 10
# TEMPERATURE: 1
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 18610/50000 (37.22 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1171/6730 (17.40%)
# 	DeathPerturbation(voronoi): 1169/6671 (17.52%)
# 	NoisePerturbation(rayleigh): 5100/7378 (69.12%)
# 	ParamPerturbation(voronoi.discretization): 2704/7202 (37.55%)
# 	ParamPerturbation(voronoi.vs): 8466/22019 (38.45%)
# Chain ID: 13
# TEMPERATURE: 1
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 18209/50000 (36.42 %)
# Chain ID: 5
# TEMPERATURE: 1
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 18315/50000 (36.63 %)
# PARTIAL ACCEPTANCE RATES:
# PARTIAL ACCEPTANCE RATES:	BirthPerturbation(voronoi): 1133/6616 (17.13%)
#
# 	DeathPerturbation(voronoi): 1130/7040 (16.05%)	BirthPerturbation(voronoi): 1181/6723 (17.57%)
#
# 	NoisePerturbation(rayleigh): 5087/7247 (70.19%)
# 	ParamPerturbation(voronoi.discretization): 2792/7270 (38.40%)
# 	ParamPerturbation(voronoi.vs): 8067/21827 (36.96%)
# 	DeathPerturbation(voronoi): 1180/7162 (16.48%)
# 	NoisePerturbation(rayleigh): 4907/7188 (68.27%)
# 	ParamPerturbation(voronoi.discretization): 2752/7102 (38.75%)
# 	ParamPerturbation(voronoi.vs): 8295/21825 (38.01%)
# Chain ID: 12
# TEMPERATURE: 1
# EXPLORED MODELS: 60000
# ACCEPTANCE RATE: 21410/60000 (35.68 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1385/8307 (16.67%)
# 	DeathPerturbation(voronoi): 1375/8015 (17.16%)
# 	NoisePerturbation(rayleigh): 6093/8791 (69.31%)
# 	ParamPerturbation(voronoi.discretization): 3217/8575 (37.52%)
# 	ParamPerturbation(voronoi.vs): 9340/26312 (35.50%)
# Chain ID: 9
# TEMPERATURE: 1
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 19477/50000 (38.95 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1264/6520 (19.39%)
# 	DeathPerturbation(voronoi): 1257/7063 (17.80%)
# 	NoisePerturbation(rayleigh): 5135/7403 (69.36%)
# 	ParamPerturbation(voronoi.discretization): 2772/7275 (38.10%)
# 	ParamPerturbation(voronoi.vs): 9049/21739 (41.63%)
# Chain ID: 2
# TEMPERATURE: 1
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 18752/50000 (37.50 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1196/6734 (17.76%)
# 	DeathPerturbation(voronoi): 1194/6983 (17.10%)
# 	NoisePerturbation(rayleigh): 4950/7185 (68.89%)
# 	ParamPerturbation(voronoi.discretization): 2689/7131 (37.71%)
# 	ParamPerturbation(voronoi.vs): 8723/21967 (39.71%)
# Chain ID: 0
# TEMPERATURE: 1
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 19396/50000 (38.79 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1165/6457 (18.04%)
# 	DeathPerturbation(voronoi): 1158/6772 (17.10%)
# 	NoisePerturbation(rayleigh): 5156/7390 (69.77%)Chain ID: 15
# TEMPERATURE: 1
# EXPLORED MODELS: 60000
# ACCEPTANCE RATE: 22032/60000 (36.72 %)
#
# 	ParamPerturbation(voronoi.discretization): 2844/7381 (38.53%)
# 	ParamPerturbation(voronoi.vs): 9073/22000 (41.24%)PARTIAL ACCEPTANCE RATES:
#
# 	BirthPerturbation(voronoi): 1417/8235 (17.21%)
# 	DeathPerturbation(voronoi): 1409/8246 (17.09%)
# 	NoisePerturbation(rayleigh): 5971/8718 (68.49%)
# 	ParamPerturbation(voronoi.discretization): 3503/8704 (40.25%)
# 	ParamPerturbation(voronoi.vs): 9732/26097 (37.29%)
# Chain ID: 16
# TEMPERATURE: 1
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 19475/50000 (38.95 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1253/6526 (19.20%)
# 	DeathPerturbation(voronoi): 1249/6949 (17.97%)
# 	NoisePerturbation(rayleigh): 5014/7381 (67.93%)
# 	ParamPerturbation(voronoi.discretization): 2843/7305 (38.92%)
# 	ParamPerturbation(voronoi.vs): 9116/21839 (41.74%)
# Chain ID: 19
# TEMPERATURE: 1
# EXPLORED MODELS: 40000
# ACCEPTANCE RATE: 15804/40000 (39.51 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 917/4506 (20.35%)
# 	DeathPerturbation(voronoi): 908/5784 (15.70%)
# 	NoisePerturbation(rayleigh): 4095/5857 (69.92%)
# Chain ID: 18
# TEMPERATURE: 1
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 20209/50000 (40.42 %)	ParamPerturbation(voronoi.discretization): 2127/5916 (35.95%)
# 	ParamPerturbation(voronoi.vs): 7757/17937 (43.25%)
#
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1413/6579 (21.48%)
# 	DeathPerturbation(voronoi): 1413/7361 (19.20%)
# 	NoisePerturbation(rayleigh): 4818/6990 (68.93%)
# 	ParamPerturbation(voronoi.discretization): 2919/7203 (40.52%)
# 	ParamPerturbation(voronoi.vs): 9646/21867 (44.11%)
# Chain ID: 6
# TEMPERATURE: 1
# EXPLORED MODELS: 60000
# ACCEPTANCE RATE: 23035/60000 (38.39 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1486/8430 (17.63%)Chain ID: 8
# TEMPERATURE: 1
# EXPLORED MODELS: 60000
# ACCEPTANCE RATE: 21417/60000 (35.70 %)
#
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1416/8263 (17.14%)
# 	DeathPerturbation(voronoi): 1475/8425 (17.51%)	DeathPerturbation(voronoi): 1416/7866 (18.00%)
# 	NoisePerturbation(rayleigh): 6105/8763 (69.67%)
# 	ParamPerturbation(voronoi.discretization): 3322/8737 (38.02%)
#
# 	NoisePerturbation(rayleigh): 5845/8535 (68.48%)
# 	ParamPerturbation(voronoi.discretization): 3422/8640 (39.61%)
# 	ParamPerturbation(voronoi.vs): 10807/25970 (41.61%)
# 	ParamPerturbation(voronoi.vs): 9158/26371 (34.73%)
# Chain ID: 4
# TEMPERATURE: 1
# EXPLORED MODELS: 60000
# ACCEPTANCE RATE: 22351/60000 (37.25 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1457/8144 (17.89%)
# 	DeathPerturbation(voronoi): 1450/8563 (16.93%)
# 	NoisePerturbation(rayleigh): 5938/8677 (68.43%)
# 	ParamPerturbation(voronoi.discretization): 3380/8638 (39.13%)
# 	ParamPerturbation(voronoi.vs): 10126/25978 (38.98%)
# Chain ID: 14
# TEMPERATURE: 1
# EXPLORED MODELS: 60000
# ACCEPTANCE RATE: 22686/60000 (37.81 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1524/8325 (18.31%)
# 	DeathPerturbation(voronoi): 1516/8450 (17.94%)Chain ID: 3
# TEMPERATURE: 1
# EXPLORED MODELS: 60000
# ACCEPTANCE RATE: 22857/60000 (38.09 %)
# 	NoisePerturbation(rayleigh): 5849/8557 (68.35%)
#
# PARTIAL ACCEPTANCE RATES:	ParamPerturbation(voronoi.discretization): 3569/8768 (40.70%)
#
# 	BirthPerturbation(voronoi): 1537/8195 (18.76%)Chain ID: 11
# TEMPERATURE: 1
# EXPLORED MODELS: 60000
# ACCEPTANCE RATE: 21637/60000 (36.06 %)
#
# 	DeathPerturbation(voronoi): 1535/8408 (18.26%)
# 	ParamPerturbation(voronoi.vs): 10228/25900 (39.49%)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1370/8132 (16.85%)
# 	NoisePerturbation(rayleigh): 5988/8730 (68.59%)
# 	ParamPerturbation(voronoi.discretization): 3452/8729 (39.55%)
# 	ParamPerturbation(voronoi.vs): 10345/25938 (39.88%)
# 	DeathPerturbation(voronoi): 1366/8108 (16.85%)
# 	NoisePerturbation(rayleigh): 6160/8872 (69.43%)
# 	ParamPerturbation(voronoi.discretization): 3351/8726 (38.40%)
# 	ParamPerturbation(voronoi.vs): 9390/26162 (35.89%)
# Chain ID: 5
# TEMPERATURE: 1
# EXPLORED MODELS: 60000
# ACCEPTANCE RATE: 21530/60000 (35.88 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1357/8253 (16.44%)
# 	DeathPerturbation(voronoi): 1353/8227 (16.45%)
# 	NoisePerturbation(rayleigh): 5995/8691 (68.98%)
# 	ParamPerturbation(voronoi.discretization): 3304/8604 (38.40%)
# 	ParamPerturbation(voronoi.vs): 9521/26225 (36.31%)
# Chain ID: 7
# TEMPERATURE: 1
# EXPLORED MODELS: 60000
# ACCEPTANCE RATE: 23015/60000 (38.36 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1489/7876 (18.91%)
# 	DeathPerturbation(voronoi): 1481/8630 (17.16%)
# 	NoisePerturbation(rayleigh): 5913/8629 (68.52%)Chain ID: 17
# TEMPERATURE: 1
# EXPLORED MODELS: 60000
# ACCEPTANCE RATE: 22827/60000 (38.05 %)
#
# PARTIAL ACCEPTANCE RATES:	ParamPerturbation(voronoi.discretization): 3408/8680 (39.26%)
# 	BirthPerturbation(voronoi): 1488/7926 (18.77%)
# 	ParamPerturbation(voronoi.vs): 10724/26185 (40.95%)
#
# 	DeathPerturbation(voronoi): 1482/8340 (17.77%)
# 	NoisePerturbation(rayleigh): 6047/8753 (69.08%)
# 	ParamPerturbation(voronoi.discretization): 3395/8770 (38.71%)
# 	ParamPerturbation(voronoi.vs): 10415/26211 (39.74%)
# Chain ID: 9
# TEMPERATURE: 1
# EXPLORED MODELS: 60000
# ACCEPTANCE RATE: 23098/60000 (38.50 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1511/7983 (18.93%)
# 	DeathPerturbation(voronoi): 1501/8483 (17.69%)
# 	NoisePerturbation(rayleigh): 6122/8845 (69.21%)
# 	ParamPerturbation(voronoi.discretization): 3318/8690 (38.18%)
# 	ParamPerturbation(voronoi.vs): 10646/25999 (40.95%)
# Chain ID: 10
# TEMPERATURE: 1
# EXPLORED MODELS: 60000
# ACCEPTANCE RATE: 22535/60000 (37.56 %)
# Chain ID: 1
# TEMPERATURE: 1
# EXPLORED MODELS: 60000
# ACCEPTANCE RATE: 23135/60000 (38.56 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1450/7699 (18.83%)
# 	DeathPerturbation(voronoi): 1444/8613 (16.77%)
# 	NoisePerturbation(rayleigh): 5889/8644 (68.13%)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1442/8007 (18.01%)
# 	DeathPerturbation(voronoi): 1437/8083 (17.78%)
# 	NoisePerturbation(rayleigh): 6060/8815 (68.75%)	ParamPerturbation(voronoi.discretization): 3333/8652 (38.52%)
# 	ParamPerturbation(voronoi.discretization): 3281/8696 (37.73%)
# 	ParamPerturbation(voronoi.vs): 10315/26399 (39.07%)
#
# 	ParamPerturbation(voronoi.vs): 11019/26392 (41.75%)
# Chain ID: 0
# TEMPERATURE: 1
# EXPLORED MODELS: 60000
# ACCEPTANCE RATE: 22641/60000 (37.73 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1369/7861 (17.42%)
# 	DeathPerturbation(voronoi): 1363/8238 (16.55%)
# 	NoisePerturbation(rayleigh): 6163/8849 (69.65%)
# 	ParamPerturbation(voronoi.discretization): 3365/8844 (38.05%)
# 	ParamPerturbation(voronoi.vs): 10381/26208 (39.61%)
# Chain ID: 13
# TEMPERATURE: 1
# EXPLORED MODELS: 60000
# ACCEPTANCE RATE: 22302/60000 (37.17 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1422/7898 (18.00%)
# 	DeathPerturbation(voronoi): 1418/8494 (16.69%)
# 	NoisePerturbation(rayleigh): 6093/8716 (69.91%)
# 	ParamPerturbation(voronoi.discretization): 3349/8659 (38.68%)
# 	ParamPerturbation(voronoi.vs): 10020/26233 (38.20%)
# Chain ID: 2
# TEMPERATURE: 1
# EXPLORED MODELS: 60000
# ACCEPTANCE RATE: 22543/60000 (37.57 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1455/8158 (17.84%)
# 	DeathPerturbation(voronoi): 1452/8364 (17.36%)
# 	NoisePerturbation(rayleigh): 5973/8650 (69.05%)
# 	ParamPerturbation(voronoi.discretization): 3266/8570 (38.11%)
# 	ParamPerturbation(voronoi.vs): 10397/26258 (39.60%)
# Chain ID: 12
# TEMPERATURE: 1
# EXPLORED MODELS: 70000
# ACCEPTANCE RATE: 25711/70000 (36.73 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1655/9523 (17.38%)
# 	DeathPerturbation(voronoi): 1653/9440 (17.51%)
# 	NoisePerturbation(rayleigh): 7091/10229 (69.32%)
# 	ParamPerturbation(voronoi.discretization): 3855/10073 (38.27%)
# 	ParamPerturbation(voronoi.vs): 11457/30735 (37.28%)
# Chain ID: 18
# TEMPERATURE: 1
# EXPLORED MODELS: 60000
# ACCEPTANCE RATE: 23534/60000 (39.22 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1605/8066 (19.90%)
# 	DeathPerturbation(voronoi): 1605/8419 (19.06%)
# 	NoisePerturbation(rayleigh): 5905/8540 (69.15%)
# Chain ID: 8
# TEMPERATURE: 1
# EXPLORED MODELS: 70000
# ACCEPTANCE RATE: 24368/70000 (34.81 %)	ParamPerturbation(voronoi.discretization): 3462/8723 (39.69%)
#
# PARTIAL ACCEPTANCE RATES:	ParamPerturbation(voronoi.vs): 10957/26252 (41.74%)
#
# 	BirthPerturbation(voronoi): 1552/9736 (15.94%)
# 	DeathPerturbation(voronoi): 1554/8746 (17.77%)
# 	NoisePerturbation(rayleigh): 7162/10257 (69.83%)
# 	ParamPerturbation(voronoi.discretization): 3765/10319 (36.49%)
# 	ParamPerturbation(voronoi.vs): 10335/30942 (33.40%)
# Chain ID: 16
# TEMPERATURE: 1
# EXPLORED MODELS: 60000
# ACCEPTANCE RATE: 23146/60000 (38.58 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1491/7912 (18.84%)
# 	DeathPerturbation(voronoi): 1489/8413 (17.70%)
# 	NoisePerturbation(rayleigh): 6052/8892 (68.06%)
# 	ParamPerturbation(voronoi.discretization): 3407/8738 (38.99%)
# 	ParamPerturbation(voronoi.vs): 10707/26045 (41.11%)
# Chain ID: 6
# TEMPERATURE: 1
# EXPLORED MODELS: 70000
# ACCEPTANCE RATE: 26228/70000 (37.47 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1671/9771 (17.10%)
# 	DeathPerturbation(voronoi): 1662/9808 (16.95%)
# 	NoisePerturbation(rayleigh): 6814/10016 (68.03%)
# 	ParamPerturbation(voronoi.discretization): 3934/10099 (38.95%)
# 	ParamPerturbation(voronoi.vs): 12147/30306 (40.08%)
# Chain ID: 15
# TEMPERATURE: 1
# EXPLORED MODELS: 70000
# ACCEPTANCE RATE: 25963/70000 (37.09 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1655/9525 (17.38%)
# 	DeathPerturbation(voronoi): 1648/9668 (17.05%)
# 	NoisePerturbation(rayleigh): 6953/10175 (68.33%)
# 	ParamPerturbation(voronoi.discretization): 4081/10215 (39.95%)
# 	ParamPerturbation(voronoi.vs): 11626/30417 (38.22%)
# Chain ID: 11
# TEMPERATURE: 1
# EXPLORED MODELS: 70000
# ACCEPTANCE RATE: 24797/70000 (35.42 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1580/9687 (16.31%)
# 	DeathPerturbation(voronoi): 1574/9269 (16.98%)
# 	NoisePerturbation(rayleigh): 7185/10317 (69.64%)
# 	ParamPerturbation(voronoi.discretization): 3915/10236 (38.25%)
# 	ParamPerturbation(voronoi.vs): 10543/30491 (34.58%)
# Chain ID: 3
# TEMPERATURE: 1
# EXPLORED MODELS: 70000
# ACCEPTANCE RATE: 26456/70000 (37.79 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1748/9594 (18.22%)
# 	DeathPerturbation(voronoi): 1742/9883 (17.63%)
# 	NoisePerturbation(rayleigh): 7007/10194 (68.74%)
# 	ParamPerturbation(voronoi.discretization): 4016/10158 (39.54%)
# 	ParamPerturbation(voronoi.vs): 11943/30171 (39.58%)
# Chain ID: 5
# TEMPERATURE: 1
# EXPLORED MODELS: 70000
# ACCEPTANCE RATE: 25315/70000 (36.16 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1613/9692 (16.64%)
# 	DeathPerturbation(voronoi): 1608/9669 (16.63%)
# 	NoisePerturbation(rayleigh): 6982/10107 (69.08%)
# 	ParamPerturbation(voronoi.discretization): 3902/10032 (38.90%)
# 	ParamPerturbation(voronoi.vs): 11210/30500 (36.75%)
# Chain ID: 7
# TEMPERATURE: 1
# EXPLORED MODELS: 70000
# ACCEPTANCE RATE: 26810/70000 (38.30 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1721/9139 (18.83%)
# 	DeathPerturbation(voronoi): 1714/10104 (16.96%)
# 	NoisePerturbation(rayleigh): 6920/10099 (68.52%)
# 	ParamPerturbation(voronoi.discretization): 3946/10146 (38.89%)
# 	ParamPerturbation(voronoi.vs): 12509/30512 (41.00%)
# Chain ID: 4
# TEMPERATURE: 1
# EXPLORED MODELS: 70000
# ACCEPTANCE RATE: 26371/70000 (37.67 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1729/9486 (18.23%)
# 	DeathPerturbation(voronoi): 1718/9982 (17.21%)
# 	NoisePerturbation(rayleigh): 6919/10114 (68.41%)
# 	ParamPerturbation(voronoi.discretization): 3969/10052 (39.48%)
# 	ParamPerturbation(voronoi.vs): 12036/30366 (39.64%)
# Chain ID: 14
# TEMPERATURE: 1
# EXPLORED MODELS: 70000
# ACCEPTANCE RATE: 26937/70000 (38.48 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 1790/9574 (18.70%)
# 	DeathPerturbation(voronoi): 1785/9880 (18.07%)
# 	NoisePerturbation(rayleigh): 6837/9961 (68.64%)
# 	ParamPerturbation(voronoi.discretization): 4201/10258 (40.95%)
# 	ParamPerturbation(voronoi.vs): 12324/30327 (40.64%)
# Chain ID: 18
# TEMPERATURE: 1
# EXPLORED MODELS: 70000
# ACCEPTANCE RATE: 26351/70000 (37.64 %)
# PARTIAL ACCEPTANCE RATES:
# ...
# 	ParamPerturbation(voronoi.discretization): 16020/40400 (39.65%)
# 	ParamPerturbation(voronoi.vs): 49188/122024 (40.31%)
# Chain ID: 8
# TEMPERATURE: 1
# EXPLORED MODELS: 290000
# ACCEPTANCE RATE: 109271/290000 (37.68 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7110/38989 (18.24%)
# 	DeathPerturbation(voronoi): 7104/39662 (17.91%)
# 	NoisePerturbation(rayleigh): 28897/41973 (68.85%)
# 	ParamPerturbation(voronoi.discretization): 16468/42263 (38.97%)
# 	ParamPerturbation(voronoi.vs): 49692/127113 (39.09%)
# Chain ID: 3
# TEMPERATURE: 1
# EXPLORED MODELS: 280000
# ACCEPTANCE RATE: 107968/280000 (38.56 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7175/37192 (19.29%)
# 	DeathPerturbation(voronoi): 7172/40288 (17.80%)
# 	NoisePerturbation(rayleigh): 27711/40471 (68.47%)
# 	ParamPerturbation(voronoi.discretization): 16040/40588 (39.52%)
# 	ParamPerturbation(voronoi.vs): 49870/121461 (41.06%)
# Chain ID: 11
# TEMPERATURE: 1
# EXPLORED MODELS: 290000
# ACCEPTANCE RATE: 108497/290000 (37.41 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7030/39460 (17.82%)
# 	DeathPerturbation(voronoi): 7027/40891 (17.18%)
# 	NoisePerturbation(rayleigh): 28942/42040 (68.84%)
# 	ParamPerturbation(voronoi.discretization): 16515/41940 (39.38%)
# 	ParamPerturbation(voronoi.vs): 48983/125669 (38.98%)
# Chain ID: 17
# TEMPERATURE: 1
# EXPLORED MODELS: 280000
# ACCEPTANCE RATE: 107316/280000 (38.33 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 6873/36528 (18.82%)
# Chain ID: 18
# TEMPERATURE: 1
# EXPLORED MODELS: 280000
# ACCEPTANCE RATE: 108071/280000 (38.60 %)	DeathPerturbation(voronoi): 6872/40049 (17.16%)
# 	NoisePerturbation(rayleigh): 28051/40795 (68.76%)
# 	ParamPerturbation(voronoi.discretization): 15646/40622 (38.52%)
#
# 	ParamPerturbation(voronoi.vs): 49874/122006 (40.88%)PARTIAL ACCEPTANCE RATES:
#
# 	BirthPerturbation(voronoi): 6957/36748 (18.93%)
# 	DeathPerturbation(voronoi): 6956/39501 (17.61%)
# 	NoisePerturbation(rayleigh): 27830/40468 (68.77%)
# 	ParamPerturbation(voronoi.discretization): 16034/40961 (39.14%)
# 	ParamPerturbation(voronoi.vs): 50294/122322 (41.12%)
# Chain ID: 9
# TEMPERATURE: 1
# EXPLORED MODELS: 300000
# ACCEPTANCE RATE: 111775/300000 (37.26 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7372/40452 (18.22%)
# 	DeathPerturbation(voronoi): 7370/41892 (17.59%)
# 	NoisePerturbation(rayleigh): 29934/43436 (68.92%)
# 	ParamPerturbation(voronoi.discretization): 16844/43446 (38.77%)
# 	ParamPerturbation(voronoi.vs): 50255/130774 (38.43%)
# Chain ID: 19
# TEMPERATURE: 1
# EXPLORED MODELS: 260000
# ACCEPTANCE RATE: 99584/260000 (38.30 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 6309/33484 (18.84%)
# 	DeathPerturbation(voronoi): 6302/37530 (16.79%)
# 	NoisePerturbation(rayleigh): 25956/37688 (68.87%)
# 	ParamPerturbation(voronoi.discretization): 14694/38051 (38.62%)
# 	ParamPerturbation(voronoi.vs): 46323/113247 (40.90%)
# Chain ID: 13
# TEMPERATURE: 1
# EXPLORED MODELS: 290000
# ACCEPTANCE RATE: 109226/290000 (37.66 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7083/38782 (18.26%)
# 	DeathPerturbation(voronoi): 7079/40858 (17.33%)
# 	NoisePerturbation(rayleigh): 29123/42154 (69.09%)
# 	ParamPerturbation(voronoi.discretization): 16174/42059 (38.46%)
# 	ParamPerturbation(voronoi.vs): 49767/126147 (39.45%)
# Chain ID: 15
# TEMPERATURE: 1
# EXPLORED MODELS: 300000
# ACCEPTANCE RATE: 113328/300000 (37.78 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7295/40013 (18.23%)
# 	DeathPerturbation(voronoi): 7293/42157 (17.30%)
# 	NoisePerturbation(rayleigh): 29627/43413 (68.24%)
# 	ParamPerturbation(voronoi.discretization): 17066/43668 (39.08%)
# 	ParamPerturbation(voronoi.vs): 52047/130749 (39.81%)
# Chain ID: 1
# TEMPERATURE: 1
# EXPLORED MODELS: 290000
# ACCEPTANCE RATE: 111103/290000 (38.31 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7295/37945 (19.23%)
# 	DeathPerturbation(voronoi): 7290/41415 (17.60%)
# 	NoisePerturbation(rayleigh): 28817/42038 (68.55%)
# 	ParamPerturbation(voronoi.discretization): 16652/42028 (39.62%)
# 	ParamPerturbation(voronoi.vs): 51049/126574 (40.33%)
# Chain ID: 2
# TEMPERATURE: 1
# EXPLORED MODELS: 290000
# ACCEPTANCE RATE: 109615/290000 (37.80 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7083/39152 (18.09%)
# 	DeathPerturbation(voronoi): 7076/40768 (17.36%)
# 	NoisePerturbation(rayleigh): 28793/41914 (68.70%)
# 	ParamPerturbation(voronoi.discretization): 16367/41915 (39.05%)
# 	ParamPerturbation(voronoi.vs): 50296/126251 (39.84%)
# Chain ID: 10
# TEMPERATURE: 1
# EXPLORED MODELS: 290000
# ACCEPTANCE RATE: 108623/290000 (37.46 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 6933/38107 (18.19%)
# 	DeathPerturbation(voronoi): 6929/41096 (16.86%)
# 	NoisePerturbation(rayleigh): 28901/41924 (68.94%)
# 	ParamPerturbation(voronoi.discretization): 15928/42165 (37.78%)
# 	ParamPerturbation(voronoi.vs): 49932/126708 (39.41%)
# Chain ID: 6
# TEMPERATURE: 1
# EXPLORED MODELS: 300000
# ACCEPTANCE RATE: 112733/300000 (37.58 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7270/40403 (17.99%)
# 	DeathPerturbation(voronoi): 7264/41631 (17.45%)
# 	NoisePerturbation(rayleigh): 29876/43583 (68.55%)
# 	ParamPerturbation(voronoi.discretization): 17003/43454 (39.13%)
# 	ParamPerturbation(voronoi.vs): 51320/130929 (39.20%)
# Chain ID: 7
# TEMPERATURE: 1
# EXPLORED MODELS: 300000
# ACCEPTANCE RATE: 113161/300000 (37.72 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7204/39558 (18.21%)
# Chain ID: 5
# TEMPERATURE: 1
# EXPLORED MODELS: 290000
# ACCEPTANCE RATE: 111515/290000 (38.45 %)
# 	DeathPerturbation(voronoi): 7200/42548 (16.92%)PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7242/38578 (18.77%)
# 	DeathPerturbation(voronoi): 7236/40833 (17.72%)
# 	NoisePerturbation(rayleigh): 28873/41973 (68.79%)
# 	ParamPerturbation(voronoi.discretization): 16667/41969 (39.71%)
# 	ParamPerturbation(voronoi.vs): 51497/126647 (40.66%)
#
# 	NoisePerturbation(rayleigh): 29970/43708 (68.57%)
# Chain ID: 4
# TEMPERATURE: 1
# EXPLORED MODELS: 290000
# ACCEPTANCE RATE: 110733/290000 (38.18 %)
# 	ParamPerturbation(voronoi.discretization): 16628/43531 (38.20%)
# PARTIAL ACCEPTANCE RATES:	ParamPerturbation(voronoi.vs): 52159/130655 (39.92%)
#
# 	BirthPerturbation(voronoi): 7208/38579 (18.68%)
# 	DeathPerturbation(voronoi): 7201/40986 (17.57%)
# 	NoisePerturbation(rayleigh): 28954/41954 (69.01%)
# 	ParamPerturbation(voronoi.discretization): 16607/41948 (39.59%)
# 	ParamPerturbation(voronoi.vs): 50763/126533 (40.12%)
# Chain ID: 14
# TEMPERATURE: 1
# EXPLORED MODELS: 290000
# ACCEPTANCE RATE: 111417/290000 (38.42 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7174/38067 (18.85%)
# 	DeathPerturbation(voronoi): 7167/40940 (17.51%)
# 	NoisePerturbation(rayleigh): 28702/41799 (68.67%)
# 	ParamPerturbation(voronoi.discretization): 16822/42395 (39.68%)
# 	ParamPerturbation(voronoi.vs): 51552/126799 (40.66%)
# Chain ID: 8
# TEMPERATURE: 1
# EXPLORED MODELS: 300000
# ACCEPTANCE RATE: 113081/300000 (37.69 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7335/40364 (18.17%)
# 	DeathPerturbation(voronoi): 7336/40966 (17.91%)
# 	NoisePerturbation(rayleigh): 29936/43447 (68.90%)
# 	ParamPerturbation(voronoi.discretization): 17079/43717 (39.07%)
# 	ParamPerturbation(voronoi.vs): 51395/131506 (39.08%)
# Chain ID: 16
# TEMPERATURE: 1
# EXPLORED MODELS: 290000
# ACCEPTANCE RATE: 110283/290000 (38.03 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7028/38592 (18.21%)
# 	DeathPerturbation(voronoi): 7021/40489 (17.34%)
# 	NoisePerturbation(rayleigh): 28894/42234 (68.41%)
# 	ParamPerturbation(voronoi.discretization): 16545/42152 (39.25%)
# 	ParamPerturbation(voronoi.vs): 50795/126533 (40.14%)
# Chain ID: 11
# TEMPERATURE: 1
# EXPLORED MODELS: 300000
# ACCEPTANCE RATE: 111431/300000 (37.14 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7179/40922 (17.54%)
# 	DeathPerturbation(voronoi): 7175/41989 (17.09%)
# 	NoisePerturbation(rayleigh): 30038/43563 (68.95%)
# 	ParamPerturbation(voronoi.discretization): 17012/43399 (39.20%)
# 	ParamPerturbation(voronoi.vs): 50027/130127 (38.44%)
# Chain ID: 0
# TEMPERATURE: 1
# EXPLORED MODELS: 280000
# ACCEPTANCE RATE: 106301/280000 (37.96 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 6591/36445 (18.08%)
# 	DeathPerturbation(voronoi): 6580/39691 (16.58%)
# 	NoisePerturbation(rayleigh): 27928/40487 (68.98%)
# 	ParamPerturbation(voronoi.discretization): 15416/41096 (37.51%)
# 	ParamPerturbation(voronoi.vs): 49786/122281 (40.71%)
# Chain ID: 3
# TEMPERATURE: 1
# EXPLORED MODELS: 290000
# ACCEPTANCE RATE: 111822/290000 (38.56 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7439/38547 (19.30%)
# 	DeathPerturbation(voronoi): 7440/41701 (17.84%)
# 	NoisePerturbation(rayleigh): 28686/41901 (68.46%)
# 	ParamPerturbation(voronoi.discretization): 16628/42037 (39.56%)
# 	ParamPerturbation(voronoi.vs): 51629/125814 (41.04%)
# Chain ID: 18
# TEMPERATURE: 1
# EXPLORED MODELS: 290000
# ACCEPTANCE RATE: 111570/290000 (38.47 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7189/38234 (18.80%)
# 	DeathPerturbation(voronoi): 7188/40927 (17.56%)
# 	NoisePerturbation(rayleigh): 28827/41910 (68.78%)
# 	ParamPerturbation(voronoi.discretization): 16543/42379 (39.04%)
# 	ParamPerturbation(voronoi.vs): 51823/126550 (40.95%)
# Chain ID: 17
# TEMPERATURE: 1
# EXPLORED MODELS: 290000
# ACCEPTANCE RATE: 110707/290000 (38.17 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7092/37876 (18.72%)
# 	DeathPerturbation(voronoi): 7093/41492 (17.09%)
# 	NoisePerturbation(rayleigh): 29028/42212 (68.77%)
# 	ParamPerturbation(voronoi.discretization): 16190/42084 (38.47%)
# 	ParamPerturbation(voronoi.vs): 51304/126336 (40.61%)
# Chain ID: 2
# TEMPERATURE: 1
# EXPLORED MODELS: 300000
# ACCEPTANCE RATE: 113277/300000 (37.76 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7315/40524 (18.05%)
# 	DeathPerturbation(voronoi): 7313/42201 (17.33%)
# 	NoisePerturbation(rayleigh): 29809/43417 (68.66%)
# 	ParamPerturbation(voronoi.discretization): 16941/43351 (39.08%)
# 	ParamPerturbation(voronoi.vs): 51899/130507 (39.77%)
# Chain ID: 19
# TEMPERATURE: 1
# EXPLORED MODELS: 270000
# ACCEPTANCE RATE: 102941/270000 (38.13 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 6537/34952 (18.70%)
# 	DeathPerturbation(voronoi): 6534/38951 (16.77%)
# 	NoisePerturbation(rayleigh): 26932/39091 (68.90%)
# 	ParamPerturbation(voronoi.discretization): 15232/39504 (38.56%)
# 	ParamPerturbation(voronoi.vs): 47706/117502 (40.60%)
# Chain ID: 13
# TEMPERATURE: 1
# EXPLORED MODELS: 300000
# ACCEPTANCE RATE: 113059/300000 (37.69 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7319/39943 (18.32%)
# 	DeathPerturbation(voronoi): 7311/42363 (17.26%)
# 	NoisePerturbation(rayleigh): 30140/43635 (69.07%)
# 	ParamPerturbation(voronoi.discretization): 16631/43512 (38.22%)
# 	ParamPerturbation(voronoi.vs): 51658/130547 (39.57%)
# Chain ID: 1
# TEMPERATURE: 1
# EXPLORED MODELS: 300000
# ACCEPTANCE RATE: 115062/300000 (38.35 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7555/39291 (19.23%)
# 	DeathPerturbation(voronoi): 7548/42848 (17.62%)
# 	NoisePerturbation(rayleigh): 29807/43429 (68.63%)
# 	ParamPerturbation(voronoi.discretization): 17205/43496 (39.56%)
# 	ParamPerturbation(voronoi.vs): 52947/130936 (40.44%)
# Chain ID: 10
# TEMPERATURE: 1
# EXPLORED MODELS: 300000
# ACCEPTANCE RATE: 112598/300000 (37.53 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7206/39458 (18.26%)
# 	DeathPerturbation(voronoi): 7202/42511 (16.94%)
# 	NoisePerturbation(rayleigh): 29927/43425 (68.92%)
# 	ParamPerturbation(voronoi.discretization): 16485/43622 (37.79%)
# 	ParamPerturbation(voronoi.vs): 51778/130984 (39.53%)
# Chain ID: 16
# TEMPERATURE: 1
# EXPLORED MODELS: 300000
# ACCEPTANCE RATE: 114264/300000 (38.09 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7306/39905 (18.31%)
# 	DeathPerturbation(voronoi): 7302/41867 (17.44%)
# 	NoisePerturbation(rayleigh): 29895/43703 (68.40%)
# 	ParamPerturbation(voronoi.discretization): 17188/43546 (39.47%)
# 	ParamPerturbation(voronoi.vs): 52573/130979 (40.14%)
# Chain ID: 0
# TEMPERATURE: 1
# EXPLORED MODELS: 290000
# ACCEPTANCE RATE: 110219/290000 (38.01 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 6835/37784 (18.09%)
# 	DeathPerturbation(voronoi): 6826/41055 (16.63%)
# 	NoisePerturbation(rayleigh): 28905/41918 (68.96%)
# 	ParamPerturbation(voronoi.discretization): 16015/42524 (37.66%)
# 	ParamPerturbation(voronoi.vs): 51638/126719 (40.75%)
# Chain ID: 4
# TEMPERATURE: 1
# EXPLORED MODELS: 300000
# ACCEPTANCE RATE: 115045/300000 (38.35 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7515/39881 (18.84%)
# 	DeathPerturbation(voronoi): 7506/42413 (17.70%)
# 	NoisePerturbation(rayleigh): 29946/43406 (68.99%)
# 	ParamPerturbation(voronoi.discretization): 17259/43435 (39.74%)
# 	ParamPerturbation(voronoi.vs): 52819/130865 (40.36%)
# Chain ID: 3
# TEMPERATURE: 1
# EXPLORED MODELS: 300000
# ACCEPTANCE RATE: 115493/300000 (38.50 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7673/39951 (19.21%)
# 	DeathPerturbation(voronoi): 7674/43013 (17.84%)
# 	NoisePerturbation(rayleigh): 29698/43329 (68.54%)
# 	ParamPerturbation(voronoi.discretization): 17195/43475 (39.55%)
# 	ParamPerturbation(voronoi.vs): 53253/130232 (40.89%)
# Chain ID: 5
# TEMPERATURE: 1
# EXPLORED MODELS: 300000
# ACCEPTANCE RATE: 115541/300000 (38.51 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7510/39863 (18.84%)
# 	DeathPerturbation(voronoi): 7500/42298 (17.73%)
# 	NoisePerturbation(rayleigh): 29891/43478 (68.75%)
# 	ParamPerturbation(voronoi.discretization): 17286/43391 (39.84%)
# 	ParamPerturbation(voronoi.vs): 53354/130970 (40.74%)
# Chain ID: 18
# TEMPERATURE: 1
# EXPLORED MODELS: 300000
# ACCEPTANCE RATE: 115468/300000 (38.49 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7462/39588 (18.85%)
# 	DeathPerturbation(voronoi): 7463/42357 (17.62%)
# 	NoisePerturbation(rayleigh): 29822/43346 (68.80%)
# 	ParamPerturbation(voronoi.discretization): 17117/43818 (39.06%)
# 	ParamPerturbation(voronoi.vs): 53604/130891 (40.95%)
# Chain ID: 14
# TEMPERATURE: 1
# EXPLORED MODELS: 300000
# ACCEPTANCE RATE: 115437/300000 (38.48 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7452/39338 (18.94%)
# 	DeathPerturbation(voronoi): 7442/42384 (17.56%)
# 	NoisePerturbation(rayleigh): 29682/43262 (68.61%)
# 	ParamPerturbation(voronoi.discretization): 17378/43884 (39.60%)
# 	ParamPerturbation(voronoi.vs): 53483/131132 (40.79%)
# Chain ID: 17
# TEMPERATURE: 1
# EXPLORED MODELS: 300000
# ACCEPTANCE RATE: 114308/300000 (38.10 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7342/39291 (18.69%)
# 	DeathPerturbation(voronoi): 7335/42890 (17.10%)
# 	NoisePerturbation(rayleigh): 30065/43686 (68.82%)
# 	ParamPerturbation(voronoi.discretization): 16747/43482 (38.51%)
# 	ParamPerturbation(voronoi.vs): 52819/130651 (40.43%)
# Chain ID: 19
# TEMPERATURE: 1
# EXPLORED MODELS: 280000
# ACCEPTANCE RATE: 106213/280000 (37.93 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 6753/36355 (18.58%)
# 	DeathPerturbation(voronoi): 6755/40357 (16.74%)
# 	NoisePerturbation(rayleigh): 27916/40537 (68.87%)
# 	ParamPerturbation(voronoi.discretization): 15717/40951 (38.38%)
# 	ParamPerturbation(voronoi.vs): 49072/121800 (40.29%)
# Chain ID: 0
# TEMPERATURE: 1
# EXPLORED MODELS: 300000
# ACCEPTANCE RATE: 114633/300000 (38.21 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7168/39114 (18.33%)
# 	DeathPerturbation(voronoi): 7163/42499 (16.85%)
# 	NoisePerturbation(rayleigh): 29950/43418 (68.98%)
# 	ParamPerturbation(voronoi.discretization): 16645/43911 (37.91%)
# 	ParamPerturbation(voronoi.vs): 53707/131058 (40.98%)
# Chain ID: 19
# TEMPERATURE: 1
# EXPLORED MODELS: 290000
# ACCEPTANCE RATE: 110166/290000 (37.99 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 6992/37577 (18.61%)
# 	DeathPerturbation(voronoi): 6986/41808 (16.71%)
# 	NoisePerturbation(rayleigh): 28876/41949 (68.84%)
# 	ParamPerturbation(voronoi.discretization): 16321/42449 (38.45%)
# 	ParamPerturbation(voronoi.vs): 50991/126217 (40.40%)
# Chain ID: 19
# TEMPERATURE: 1
# EXPLORED MODELS: 300000
# ACCEPTANCE RATE: 114280/300000 (38.09 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 7276/38937 (18.69%)
# 	DeathPerturbation(voronoi): 7275/43274 (16.81%)
# 	NoisePerturbation(rayleigh): 29890/43447 (68.80%)
# 	ParamPerturbation(voronoi.discretization): 16896/43881 (38.50%)
# 	ParamPerturbation(voronoi.vs): 52943/130461 (40.58%)

# %%
results = inversion.get_results(concatenate_chains=True)

sampled_voronoi_nuclei = results['voronoi.discretization']
sampled_thickness = [Voronoi1D.compute_cell_extents(n) for n in sampled_voronoi_nuclei]
sampled_vs = results['voronoi.vs']
interp_depths = np.linspace(0, 160, 160)
statistics_vs = Voronoi1D.get_depth_profiles_statistics(
    sampled_thickness, sampled_vs, interp_depths
    )

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(6, 8), gridspec_kw={'width_ratios': [2.5, 1]})
ax1, cbar = Voronoi1D.plot_depth_profile_density(
    sampled_thickness, sampled_vs, ax=ax1, cmap='binary', vmin=0, vmax=2000
)
Voronoi1D.plot_depth_profile(THICKNESS, VS, ax=ax1, color='yellow', lw=3, label='True Vs')
ax1.plot(statistics_vs['mean'], interp_depths, 'b', lw=2, label='Vs Ensemble Mean')
ax1.plot(statistics_vs['median'], interp_depths, 'r', lw=2, label='Vs Ensemble Median')
ax1.set_xlabel("Vs [km/s]")
ax1.set_ylabel("Depth [km]")
ax1.legend()

Voronoi1D.plot_interface_hist(sampled_thickness, bins=75, ec='w', ax=ax2)
ax2.tick_params(labelleft=False)
ax2.set_ylabel('')
ax2.set_ylim(*ax1.get_ylim())
plt.tight_layout()
plt.show()

# %%
d_pred = np.array(results['rayleigh.dpred'])
percentiles = np.percentile(d_pred, (10, 90), axis=0)

# Predicted dispersion curves
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 6))
ax1.plot(PERIODS, phase_vel, 'r--', label='Rayleigh (true Vs)', lw=0.5)
ax1.plot(PERIODS, d_obs, 'ro', label='Observations')
ax1.fill_between(PERIODS, percentiles[0], percentiles[1], color='r', alpha=0.2, label='Inferred Data (10th-90th percentiles)', zorder=100)
ax1.set_xlabel('Period [s]')
ax1.set_ylabel('Phase velocity [km/s]')
ax1.grid()
ax1.legend()

# Histogram of inferred data noise
ax2.axvline(x=RAYLEIGH_STD, color='r', lw=3, alpha=0.3, label='True data noise')
pdf, bins, _ = ax2.hist(results['rayleigh.std'], density=True, bins=20, ec='w', zorder=100, label='Posterior')
ax2.fill_between([target.std_min, target.std_max], 1 / (target.std_max - target.std_min), alpha=0.2, label='Prior')
ax2.set_xlabel('Noise standard deviation')
ax2.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
ax2.legend(framealpha=0.9)
plt.tight_layout()
plt.show()

# %%
def get_subplot_layout(n_subplots):
    rows = int(np.sqrt(n_subplots))
    cols = int(np.ceil(n_subplots / rows))
    return rows, cols

rows, cols = get_subplot_layout(len(inversion.chains))
fig, axes = plt.subplots(rows, cols, figsize=(15, 15))
for ipanel, (ax, chain) in enumerate(zip(np.ravel(axes), inversion.chains)):
    saved_states = chain.saved_states
    saved_thickness = saved_states["voronoi.discretization"]
    saved_vs = saved_states['voronoi.vs']
    
    Voronoi1D.plot_depth_profiles(
    saved_thickness, saved_vs, ax=ax, linewidth=0.1, color="k", max_depth=150
)
    Voronoi1D.plot_depth_profile(THICKNESS, VS, color='yellow', lw=2, ax=ax)
    Voronoi1D.plot_depth_profiles_statistics(
        saved_thickness, saved_vs, interp_depths, ax=ax
    )
    
    ax.set_title(f'Chain {chain.id}')
    ax.tick_params(direction='in', labelleft=False, labelbottom=False)
    ax.set_xlabel('')
    ax.set_ylabel('')
    
    if not ipanel % cols:
        ax.set_ylabel('Depth [km]')
        ax.tick_params(labelleft=True)
    if ipanel >= (rows-1) * cols:
        ax.set_xlabel('Vs [km/s]')
        ax.tick_params(labelbottom=True)
    
plt.tight_layout()
plt.show()
