# %% [markdown]
# (rayleigh)=
# # Part I: Rayleigh

# %%
import bayesbay as bb
from bayesbay.discretization import Voronoi1D
import numpy as np
import matplotlib.pyplot as plt
from disba import PhaseDispersion
np.random.seed(30)

# %%
THICKNESS = np.array([10, 10, 15, 20, 20, 20, 20, 20, 0])
VS = np.array([3.38, 3.44, 3.66, 4.25, 4.35, 4.32, 4.315, 4.38, 4.5])
VP_VS = 1.77
VP = VS * VP_VS
RHO = 0.32 * VP + 0.77
PERIODS = np.geomspace(3, 80, 20)
RAYLEIGH_STD = 0.02

# %%
def initialize_vs(param, positions=None):
    vmin, vmax = param.get_vmin_vmax(positions)
    sorted_vals = np.sort(np.random.uniform(vmin, vmax, positions.size))
    return sorted_vals

vs = bb.prior.UniformPrior(name="vs", 
                                    vmin=[2.2, 2.8, 3.3, 4], 
                                    vmax=[3.9, 4.6, 4.8, 5], 
                                    position=[0, 20, 60, 150],
                                    perturb_std=0.15)
vs.set_custom_initialize(initialize_vs)

# %%
pd = PhaseDispersion(THICKNESS, VP, VS, RHO)
phase_vel = pd(PERIODS, mode=0, wave="rayleigh").velocity
d_obs = phase_vel + np.random.normal(0, RAYLEIGH_STD, phase_vel.size)

# %%
# For plotting the prior
depth_prior = np.linspace(0, 200)
vmin_prior, vmax_prior = vs.get_vmin_vmax(depth_prior)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4), gridspec_kw={'width_ratios': [1, 2.5]})
ax1.fill_betweenx(depth_prior, vmin_prior, vmax_prior, alpha=0.2, label='Prior')
Voronoi1D.plot_depth_profile(THICKNESS, VS, label='True Vs', ax=ax1, color='k', lw=2)
ax1.set_xlabel('Vs [km/s]')
ax1.set_ylabel('Depth [km]')
ax1.set_ylim(np.cumsum(THICKNESS)[-1] + max(THICKNESS), 0)
ax1.grid()
ax1.legend()

ax2.plot(PERIODS, phase_vel, 'r--', label='Rayleigh (true Vs)', lw=0.5)
ax2.plot(PERIODS, d_obs, 'ro', label='Rayleigh obs.')
ax2.set_xlabel('Period [s]')
ax2.set_ylabel('Phase velocity [km/s]')
ax2.grid()
ax2.legend()

plt.tight_layout(w_pad=2)
plt.show()

# %%
voronoi = Voronoi1D(
    name="voronoi", 
    vmin=0,
    vmax=150,
    perturb_std=10,
    n_dimensions=None, 
    n_dimensions_min=4,
    n_dimensions_max=15,
    parameters=[vs], 
    birth_from='neighbour'
)
parameterization = bb.parameterization.Parameterization(voronoi)

# %%
def forward_sw(state):
    voronoi = state["voronoi"]
    voronoi_sites = voronoi["discretization"]
    thickness = Voronoi1D.compute_cell_extents(voronoi_sites)
    vs = voronoi["vs"]
    vp = vs * VP_VS
    rho = 0.32 * vp + 0.77
    pd = PhaseDispersion(thickness, vp, vs, rho)
    d_pred = pd(PERIODS, mode=0, wave="rayleigh").velocity
    return d_pred

# %%
target = bb.Target("rayleigh", 
                   d_obs, 
                   std_min=0.001, 
                   std_max=0.1, 
                   std_perturb_std=0.002)

# %%
log_likelihood = bb.LogLikelihood(targets=target, fwd_functions=forward_sw)

inversion = bb.BayesianInversion(
    parameterization=parameterization, 
    log_likelihood=log_likelihood,
    n_chains=20
)
inversion.run(
    sampler=None, 
    n_iterations=350_000, 
    burnin_iterations=75_000, 
    save_every=150,
    verbose=False
)

# %%
for chain in inversion.chains:
    chain.print_statistics()
# Out:
# Chain ID: 0
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 161260/350000 (46.07 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10534/47687 (22.09%)
# 	DeathPerturbation(voronoi): 10535/47606 (22.13%)
# 	NoisePerturbation(rayleigh): 43376/50950 (85.13%)
# 	ParamPerturbation(voronoi.discretization): 24280/50879 (47.72%)
# 	ParamPerturbation(voronoi.vs): 72535/152878 (47.45%)
# Chain ID: 1
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 166959/350000 (47.70 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10935/47054 (23.24%)
# 	DeathPerturbation(voronoi): 10931/48481 (22.55%)
# 	NoisePerturbation(rayleigh): 43593/50845 (85.74%)
# 	ParamPerturbation(voronoi.discretization): 24461/50767 (48.18%)
# 	ParamPerturbation(voronoi.vs): 77039/152853 (50.40%)
# Chain ID: 2
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 164612/350000 (47.03 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10923/47605 (22.95%)
# 	DeathPerturbation(voronoi): 10918/48236 (22.63%)
# 	NoisePerturbation(rayleigh): 43186/50577 (85.39%)
# 	ParamPerturbation(voronoi.discretization): 24646/50754 (48.56%)
# 	ParamPerturbation(voronoi.vs): 74939/152828 (49.03%)
# Chain ID: 3
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 162902/350000 (46.54 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10638/47477 (22.41%)
# 	DeathPerturbation(voronoi): 10638/47430 (22.43%)
# 	NoisePerturbation(rayleigh): 43573/51037 (85.38%)
# 	ParamPerturbation(voronoi.discretization): 24245/51018 (47.52%)
# 	ParamPerturbation(voronoi.vs): 73808/153038 (48.23%)
# Chain ID: 4
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 163999/350000 (46.86 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10782/47149 (22.87%)
# 	DeathPerturbation(voronoi): 10774/48091 (22.40%)
# 	NoisePerturbation(rayleigh): 43616/51011 (85.50%)
# 	ParamPerturbation(voronoi.discretization): 24703/51551 (47.92%)
# 	ParamPerturbation(voronoi.vs): 74124/152198 (48.70%)
# Chain ID: 5
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 164764/350000 (47.08 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10821/47083 (22.98%)
# 	DeathPerturbation(voronoi): 10816/47988 (22.54%)
# 	NoisePerturbation(rayleigh): 43544/51014 (85.36%)
# 	ParamPerturbation(voronoi.discretization): 24440/50848 (48.06%)
# 	ParamPerturbation(voronoi.vs): 75143/153067 (49.09%)
# Chain ID: 6
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 167828/350000 (47.95 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 11027/45986 (23.98%)
# 	DeathPerturbation(voronoi): 11024/49428 (22.30%)
# 	NoisePerturbation(rayleigh): 43270/50675 (85.39%)
# 	ParamPerturbation(voronoi.discretization): 24358/50742 (48.00%)
# 	ParamPerturbation(voronoi.vs): 78149/153169 (51.02%)
# Chain ID: 7
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 164181/350000 (46.91 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10726/47241 (22.70%)
# 	DeathPerturbation(voronoi): 10726/47734 (22.47%)
# 	NoisePerturbation(rayleigh): 43728/51218 (85.38%)
# 	ParamPerturbation(voronoi.discretization): 24669/51195 (48.19%)
# 	ParamPerturbation(voronoi.vs): 74332/152612 (48.71%)
# Chain ID: 8
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 165776/350000 (47.36 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 11008/46952 (23.45%)
# 	DeathPerturbation(voronoi): 10999/48843 (22.52%)
# 	NoisePerturbation(rayleigh): 43316/50720 (85.40%)
# 	ParamPerturbation(voronoi.discretization): 24630/50845 (48.44%)
# 	ParamPerturbation(voronoi.vs): 75823/152640 (49.67%)
# Chain ID: 9
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 165848/350000 (47.39 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 11032/46939 (23.50%)
# 	DeathPerturbation(voronoi): 11024/48584 (22.69%)
# 	NoisePerturbation(rayleigh): 43560/50874 (85.62%)
# 	ParamPerturbation(voronoi.discretization): 24539/50590 (48.51%)
# 	ParamPerturbation(voronoi.vs): 75693/153013 (49.47%)
# Chain ID: 10
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 166809/350000 (47.66 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 11084/46992 (23.59%)
# 	DeathPerturbation(voronoi): 11078/48990 (22.61%)
# 	NoisePerturbation(rayleigh): 43501/50866 (85.52%)
# 	ParamPerturbation(voronoi.discretization): 24640/50805 (48.50%)
# 	ParamPerturbation(voronoi.vs): 76506/152347 (50.22%)
# Chain ID: 11
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 169126/350000 (48.32 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 11153/46179 (24.15%)
# 	DeathPerturbation(voronoi): 11154/48866 (22.83%)
# 	NoisePerturbation(rayleigh): 43571/50912 (85.58%)
# 	ParamPerturbation(voronoi.discretization): 24892/50838 (48.96%)
# 	ParamPerturbation(voronoi.vs): 78356/153205 (51.14%)
# Chain ID: 12
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 168183/350000 (48.05 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10919/45716 (23.88%)
# 	DeathPerturbation(voronoi): 10918/48977 (22.29%)
# 	NoisePerturbation(rayleigh): 43757/51336 (85.24%)
# 	ParamPerturbation(voronoi.discretization): 24762/51057 (48.50%)
# 	ParamPerturbation(voronoi.vs): 77827/152914 (50.90%)
# Chain ID: 13
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 162700/350000 (46.49 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10698/47318 (22.61%)
# 	DeathPerturbation(voronoi): 10692/47784 (22.38%)
# 	NoisePerturbation(rayleigh): 43703/51041 (85.62%)
# 	ParamPerturbation(voronoi.discretization): 23897/50845 (47.00%)
# 	ParamPerturbation(voronoi.vs): 73710/153012 (48.17%)
# Chain ID: 14
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 165743/350000 (47.36 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10805/46321 (23.33%)
# 	DeathPerturbation(voronoi): 10798/48260 (22.37%)
# 	NoisePerturbation(rayleigh): 43383/51066 (84.95%)
# 	ParamPerturbation(voronoi.discretization): 24273/51033 (47.56%)
# 	ParamPerturbation(voronoi.vs): 76484/153320 (49.89%)
# Chain ID: 15
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 163398/350000 (46.69 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10762/47495 (22.66%)
# 	DeathPerturbation(voronoi): 10754/46650 (23.05%)
# 	NoisePerturbation(rayleigh): 43733/51190 (85.43%)
# 	ParamPerturbation(voronoi.discretization): 24655/51398 (47.97%)
# 	ParamPerturbation(voronoi.vs): 73494/153267 (47.95%)
# Chain ID: 16
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 164115/350000 (46.89 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10593/47013 (22.53%)
# 	DeathPerturbation(voronoi): 10588/47830 (22.14%)
# 	NoisePerturbation(rayleigh): 43844/51377 (85.34%)
# 	ParamPerturbation(voronoi.discretization): 24593/50792 (48.42%)
# 	ParamPerturbation(voronoi.vs): 74497/152988 (48.69%)
# Chain ID: 17
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 166329/350000 (47.52 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10962/47217 (23.22%)
# 	DeathPerturbation(voronoi): 10956/47341 (23.14%)
# 	NoisePerturbation(rayleigh): 43728/51018 (85.71%)
# 	ParamPerturbation(voronoi.discretization): 24438/50887 (48.02%)
# 	ParamPerturbation(voronoi.vs): 76245/153537 (49.66%)
# Chain ID: 18
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 167032/350000 (47.72 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10907/45715 (23.86%)
# 	DeathPerturbation(voronoi): 10900/48810 (22.33%)
# 	NoisePerturbation(rayleigh): 43816/51391 (85.26%)
# 	ParamPerturbation(voronoi.discretization): 24604/51158 (48.09%)
# 	ParamPerturbation(voronoi.vs): 76805/152926 (50.22%)
# Chain ID: 19
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 167701/350000 (47.91 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 10905/46317 (23.54%)
# 	DeathPerturbation(voronoi): 10898/48586 (22.43%)
# 	NoisePerturbation(rayleigh): 43395/50721 (85.56%)
# 	ParamPerturbation(voronoi.discretization): 25036/51058 (49.03%)
# 	ParamPerturbation(voronoi.vs): 77467/153318 (50.53%)

# %%
results = inversion.get_results(concatenate_chains=True)

sampled_voronoi_nuclei = results['voronoi.discretization']
sampled_thickness = [Voronoi1D.compute_cell_extents(n) for n in sampled_voronoi_nuclei]
sampled_vs = results['voronoi.vs']
interp_depths = np.linspace(0, 160, 160)
statistics_vs = Voronoi1D.get_depth_profiles_statistics(
    sampled_thickness, sampled_vs, interp_depths
    )

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(6, 8), gridspec_kw={'width_ratios': [2.5, 1]})
ax1, cbar = Voronoi1D.plot_depth_profile_density(
    sampled_thickness, sampled_vs, ax=ax1, cmap='binary', vmin=0, vmax=2000
)
Voronoi1D.plot_depth_profile(THICKNESS, VS, ax=ax1, color='yellow', lw=3, label='True Vs')
ax1.plot(statistics_vs['mean'], interp_depths, 'b', lw=2, label='Vs Ensemble Mean')
ax1.plot(statistics_vs['median'], interp_depths, 'r', lw=2, label='Vs Ensemble Median')
ax1.set_xlabel("Vs [km/s]")
ax1.set_ylabel("Depth [km]")
ax1.legend()

Voronoi1D.plot_interface_hist(sampled_thickness, bins=75, ec='w', ax=ax2)
ax2.tick_params(labelleft=False)
ax2.set_ylabel('')
ax2.set_ylim(*ax1.get_ylim())
plt.tight_layout()
plt.show()

# %%
d_pred = np.array(results['rayleigh.dpred'])
percentiles = np.percentile(d_pred, (10, 90), axis=0)

# Predicted dispersion curves
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 6))
ax1.plot(PERIODS, phase_vel, 'r--', label='Rayleigh (true Vs)', lw=0.5)
ax1.plot(PERIODS, d_obs, 'ro', label='Observations')
ax1.fill_between(PERIODS, percentiles[0], percentiles[1], color='r', alpha=0.2, label='Inferred Data (10th-90th percentiles)', zorder=100)
ax1.set_xlabel('Period [s]')
ax1.set_ylabel('Phase velocity [km/s]')
ax1.grid()
ax1.legend()

# Histogram of inferred data noise
ax2.axvline(x=RAYLEIGH_STD, color='r', lw=3, alpha=0.3, label='True data noise')
pdf, bins, _ = ax2.hist(results['rayleigh.std'], density=True, bins=20, ec='w', zorder=100, label='Posterior')
ax2.fill_between([target.std_min, target.std_max], 1 / (target.std_max - target.std_min), alpha=0.2, label='Prior')
ax2.set_xlabel('Noise standard deviation')
ax2.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
ax2.legend(framealpha=0.9)
plt.tight_layout()
plt.show()

# %%
def get_subplot_layout(n_subplots):
    rows = int(np.sqrt(n_subplots))
    cols = int(np.ceil(n_subplots / rows))
    return rows, cols

rows, cols = get_subplot_layout(len(inversion.chains))
fig, axes = plt.subplots(rows, cols, figsize=(15, 15))
for ipanel, (ax, chain) in enumerate(zip(np.ravel(axes), inversion.chains)):
    saved_states = chain.saved_states
    saved_thickness = saved_states["voronoi.discretization"]
    saved_vs = saved_states['voronoi.vs']
    
    Voronoi1D.plot_depth_profiles(
    saved_thickness, saved_vs, ax=ax, linewidth=0.1, color="k", max_depth=150
)
    Voronoi1D.plot_depth_profile(THICKNESS, VS, color='yellow', lw=2, ax=ax)
    Voronoi1D.plot_depth_profiles_statistics(
        saved_thickness, saved_vs, interp_depths, ax=ax
    )
    
    ax.set_title(f'Chain {chain.id}')
    ax.tick_params(direction='in', labelleft=False, labelbottom=False)
    ax.set_xlabel('')
    ax.set_ylabel('')
    
    if not ipanel % cols:
        ax.set_ylabel('Depth [km]')
        ax.tick_params(labelleft=True)
    if ipanel >= (rows-1) * cols:
        ax.set_xlabel('Vs [km/s]')
        ax.tick_params(labelbottom=True)
    
plt.tight_layout()
plt.show()
