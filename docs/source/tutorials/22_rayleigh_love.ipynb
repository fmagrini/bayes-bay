# %% [markdown]
# (rayleigh_love)=
# # Part II: Rayleigh and Love

# %%
import bayesbay as bb
from bayesbay.discretization import Voronoi1D
import numpy as np
import matplotlib.pyplot as plt
from disba import PhaseDispersion
np.random.seed(30)

# %%
THICKNESS = np.array([10, 10, 15, 20, 20, 20, 20, 20, 0])
VS = np.array([3.38, 3.44, 3.66, 4.25, 4.35, 4.32, 4.315, 4.38, 4.5])
VP_VS = 1.77
VP = VS * VP_VS
RHO = 0.32 * VP + 0.77
PERIODS = np.geomspace(3, 80, 20)
RAYLEIGH_STD = 0.02
LOVE_STD = 0.02

# %%
def initialize_vs(param, positions=None):
    vmin, vmax = param.get_vmin_vmax(positions)
    sorted_vals = np.sort(np.random.uniform(vmin, vmax, positions.size))
    return sorted_vals

vs = bb.prior.UniformPrior(name="vs", 
                                    vmin=[2.2, 2.8, 3.3, 4], 
                                    vmax=[3.9, 4.6, 4.8, 5], 
                                    position=[0, 20, 60, 150],
                                    perturb_std=0.15)
vs.set_custom_initialize(initialize_vs)

# %%
pd = PhaseDispersion(THICKNESS, VP, VS, RHO)
rayleigh = pd(PERIODS, mode=0, wave="rayleigh").velocity
love = pd(PERIODS, mode=0, wave="love").velocity
rayleigh_obs = rayleigh + np.random.normal(0, RAYLEIGH_STD, rayleigh.size)
love_obs = love + np.random.normal(0, LOVE_STD, love.size)

# %%
# For plotting the prior
depth_prior = np.linspace(0, 200)
vmin_prior, vmax_prior = vs.get_vmin_vmax(depth_prior)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4), gridspec_kw={'width_ratios': [1, 2.5]})
ax1.fill_betweenx(depth_prior, vmin_prior, vmax_prior, alpha=0.2, label='Prior')
Voronoi1D.plot_depth_profile(THICKNESS, VS, label='True Vs', ax=ax1, color='k', lw=2)
ax1.set_xlabel('Vs [km/s]')
ax1.set_ylabel('Depth [km]')
ax1.set_ylim(np.cumsum(THICKNESS)[-1] + max(THICKNESS), 0)
ax1.grid()
ax1.legend()

ax2.plot(PERIODS, rayleigh, 'r--', label='Rayleigh (true Vs)', lw=0.5)
ax2.plot(PERIODS, love, 'b--', label='Love (true Vs)', lw=0.5)
ax2.plot(PERIODS, rayleigh_obs, 'ro', label='Noisy Rayleigh')
ax2.plot(PERIODS, love_obs, 'bo', label='Noisy Love')
ax2.set_xlabel('Period [s]')
ax2.set_ylabel('Phase velocity [km/s]')
ax2.grid()
ax2.legend()

plt.tight_layout(w_pad=2)
plt.show()

# %%
voronoi = Voronoi1D(
    name="voronoi", 
    vmin=0,
    vmax=150,
    perturb_std=10,
    n_dimensions=None, 
    n_dimensions_min=4,
    n_dimensions_max=15,
    parameters=[vs], 
    birth_from='neighbour'
)
parameterization = bb.parameterization.Parameterization(voronoi)

# %%
def forward_sw(state, wave='rayleigh', mode=0):
    voronoi = state["voronoi"]
    voronoi_sites = voronoi["discretization"]
    thickness = Voronoi1D.compute_cell_extents(voronoi_sites)
    vs = voronoi["vs"]
    vp = vs * VP_VS
    rho = 0.32 * vp + 0.77
    pd = PhaseDispersion(thickness, vp, vs, rho)
    d_pred = pd(PERIODS, mode=mode, wave=wave).velocity
    return d_pred

# %%
from functools import partial

forward_rayleigh = partial(forward_sw, wave='rayleigh', mode=0)
forward_love = partial(forward_sw, wave='love', mode=0)

# %%
target_rayleigh = bb.Target("rayleigh", 
                            rayleigh_obs, 
                            std_min=0.001, 
                            std_max=0.1, 
                            std_perturb_std=0.002)
target_love = bb.Target("love", 
                        love_obs, 
                        std_min=0.001, 
                        std_max=0.1, 
                        std_perturb_std=0.002)

# %%
log_likelihood = bb.LogLikelihood(
    targets=[target_rayleigh, target_love], 
    fwd_functions=[forward_rayleigh, forward_love]
)

inversion = bb.BayesianInversion(
    parameterization=parameterization, 
    log_likelihood=log_likelihood,
    n_chains=20
)

inversion.run(
    sampler=None, 
    n_iterations=350_000, 
    burnin_iterations=75_000, 
    save_every=150, 
    verbose=False
)

# %%
for chain in inversion.chains:
    chain.print_statistics()
# Out:
# Chain ID: 0
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 138382/350000 (39.54 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 9354/49079 (19.06%)
# 	DeathPerturbation(voronoi): 9351/45851 (20.39%)
# 	NoisePerturbation(['rayleigh', 'love']): 39311/51189 (76.80%)
# 	ParamPerturbation(voronoi.discretization): 22466/50750 (44.27%)
# 	ParamPerturbation(voronoi.vs): 57900/153131 (37.81%)
# Chain ID: 1
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 134931/350000 (38.55 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 9105/49803 (18.28%)
# 	DeathPerturbation(voronoi): 9101/45454 (20.02%)
# 	NoisePerturbation(['rayleigh', 'love']): 39741/51412 (77.30%)
# 	ParamPerturbation(voronoi.discretization): 22139/50624 (43.73%)
# 	ParamPerturbation(voronoi.vs): 54845/152707 (35.92%)
# Chain ID: 2
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 140694/350000 (40.20 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 9642/49437 (19.50%)
# 	DeathPerturbation(voronoi): 9634/45786 (21.04%)
# 	NoisePerturbation(['rayleigh', 'love']): 39488/51111 (77.26%)
# 	ParamPerturbation(voronoi.discretization): 22867/50964 (44.87%)
# 	ParamPerturbation(voronoi.vs): 59063/152702 (38.68%)
# Chain ID: 3
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 139274/350000 (39.79 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 9548/49232 (19.39%)
# 	DeathPerturbation(voronoi): 9546/46167 (20.68%)
# 	NoisePerturbation(['rayleigh', 'love']): 39320/50837 (77.35%)
# 	ParamPerturbation(voronoi.discretization): 22344/50624 (44.14%)
# 	ParamPerturbation(voronoi.vs): 58516/153140 (38.21%)
# Chain ID: 4
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 136337/350000 (38.95 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 9264/49595 (18.68%)
# 	DeathPerturbation(voronoi): 9264/44776 (20.69%)
# 	NoisePerturbation(['rayleigh', 'love']): 39575/51223 (77.26%)
# 	ParamPerturbation(voronoi.discretization): 22325/51156 (43.64%)
# 	ParamPerturbation(voronoi.vs): 55909/153250 (36.48%)
# Chain ID: 5
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 136246/350000 (38.93 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 9261/49503 (18.71%)
# 	DeathPerturbation(voronoi): 9262/45103 (20.54%)
# 	NoisePerturbation(['rayleigh', 'love']): 39628/51432 (77.05%)
# 	ParamPerturbation(voronoi.discretization): 22387/50717 (44.14%)
# 	ParamPerturbation(voronoi.vs): 55708/153245 (36.35%)
# Chain ID: 6
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 137831/350000 (39.38 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 9436/49382 (19.11%)
# 	DeathPerturbation(voronoi): 9437/46051 (20.49%)
# 	NoisePerturbation(['rayleigh', 'love']): 39546/51179 (77.27%)
# 	ParamPerturbation(voronoi.discretization): 22496/50945 (44.16%)
# 	ParamPerturbation(voronoi.vs): 56916/152443 (37.34%)
# Chain ID: 7
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 135474/350000 (38.71 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 9303/49366 (18.84%)
# 	DeathPerturbation(voronoi): 9294/45322 (20.51%)
# 	NoisePerturbation(['rayleigh', 'love']): 39131/50881 (76.91%)
# 	ParamPerturbation(voronoi.discretization): 22017/51039 (43.14%)
# 	ParamPerturbation(voronoi.vs): 55729/153392 (36.33%)
# Chain ID: 8
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 138047/350000 (39.44 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 9367/49416 (18.96%)
# 	DeathPerturbation(voronoi): 9363/46442 (20.16%)
# 	NoisePerturbation(['rayleigh', 'love']): 39013/50739 (76.89%)
# 	ParamPerturbation(voronoi.discretization): 22615/50870 (44.46%)
# 	ParamPerturbation(voronoi.vs): 57689/152533 (37.82%)
# Chain ID: 9
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 136297/350000 (38.94 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 9317/49212 (18.93%)
# 	DeathPerturbation(voronoi): 9317/46294 (20.13%)
# 	NoisePerturbation(['rayleigh', 'love']): 39137/50727 (77.15%)
# 	ParamPerturbation(voronoi.discretization): 22443/50827 (44.16%)
# 	ParamPerturbation(voronoi.vs): 56083/152940 (36.67%)
# Chain ID: 10
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 136676/350000 (39.05 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 9257/49507 (18.70%)
# 	DeathPerturbation(voronoi): 9258/45693 (20.26%)
# 	NoisePerturbation(['rayleigh', 'love']): 39209/50821 (77.15%)
# 	ParamPerturbation(voronoi.discretization): 22022/50525 (43.59%)
# 	ParamPerturbation(voronoi.vs): 56930/153454 (37.10%)
# Chain ID: 11
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 138068/350000 (39.45 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 9236/48602 (19.00%)
# 	DeathPerturbation(voronoi): 9235/45424 (20.33%)
# 	NoisePerturbation(['rayleigh', 'love']): 39784/51342 (77.49%)
# 	ParamPerturbation(voronoi.discretization): 22528/50967 (44.20%)
# 	ParamPerturbation(voronoi.vs): 57285/153665 (37.28%)
# Chain ID: 12
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 135537/350000 (38.72 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 9227/49583 (18.61%)
# 	DeathPerturbation(voronoi): 9218/44865 (20.55%)
# 	NoisePerturbation(['rayleigh', 'love']): 39321/51180 (76.83%)
# 	ParamPerturbation(voronoi.discretization): 22279/51155 (43.55%)
# 	ParamPerturbation(voronoi.vs): 55492/153217 (36.22%)
# Chain ID: 13
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 139907/350000 (39.97 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 9488/49068 (19.34%)
# 	DeathPerturbation(voronoi): 9489/46549 (20.38%)
# 	NoisePerturbation(['rayleigh', 'love']): 39099/50645 (77.20%)
# 	ParamPerturbation(voronoi.discretization): 22731/50765 (44.78%)
# 	ParamPerturbation(voronoi.vs): 59100/152973 (38.63%)
# Chain ID: 14
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 142757/350000 (40.79 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 9856/48545 (20.30%)
# 	DeathPerturbation(voronoi): 9849/47331 (20.81%)
# 	NoisePerturbation(['rayleigh', 'love']): 39185/51002 (76.83%)
# 	ParamPerturbation(voronoi.discretization): 22665/50918 (44.51%)
# 	ParamPerturbation(voronoi.vs): 61202/152204 (40.21%)
# Chain ID: 15
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 136742/350000 (39.07 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 9269/49187 (18.84%)
# 	DeathPerturbation(voronoi): 9265/45013 (20.58%)
# 	NoisePerturbation(['rayleigh', 'love']): 39624/51308 (77.23%)
# 	ParamPerturbation(voronoi.discretization): 22042/50947 (43.26%)
# 	ParamPerturbation(voronoi.vs): 56542/153545 (36.82%)
# Chain ID: 16
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 133662/350000 (38.19 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 9198/50039 (18.38%)
# 	DeathPerturbation(voronoi): 9192/44626 (20.60%)
# 	NoisePerturbation(['rayleigh', 'love']): 39301/51155 (76.83%)
# 	ParamPerturbation(voronoi.discretization): 22082/51114 (43.20%)
# 	ParamPerturbation(voronoi.vs): 53889/153066 (35.21%)
# Chain ID: 17
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 138631/350000 (39.61 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 9472/49134 (19.28%)
# 	DeathPerturbation(voronoi): 9472/45794 (20.68%)
# 	NoisePerturbation(['rayleigh', 'love']): 39655/51260 (77.36%)
# 	ParamPerturbation(voronoi.discretization): 22563/51233 (44.04%)
# 	ParamPerturbation(voronoi.vs): 57469/152579 (37.67%)
# Chain ID: 18
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 134471/350000 (38.42 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 9096/49807 (18.26%)
# 	DeathPerturbation(voronoi): 9093/45106 (20.16%)
# 	NoisePerturbation(['rayleigh', 'love']): 39419/51231 (76.94%)
# 	ParamPerturbation(voronoi.discretization): 22003/50977 (43.16%)
# 	ParamPerturbation(voronoi.vs): 54860/152879 (35.88%)
# Chain ID: 19
# TEMPERATURE: 1
# EXPLORED MODELS: 350000
# ACCEPTANCE RATE: 132446/350000 (37.84 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(voronoi): 8757/49978 (17.52%)
# 	DeathPerturbation(voronoi): 8753/42800 (20.45%)
# 	NoisePerturbation(['rayleigh', 'love']): 39800/51344 (77.52%)
# 	ParamPerturbation(voronoi.discretization): 22007/51252 (42.94%)
# 	ParamPerturbation(voronoi.vs): 53129/154626 (34.36%)

# %%
results = inversion.get_results(concatenate_chains=True)

sampled_voronoi_nuclei = results['voronoi.discretization']
sampled_thickness = [Voronoi1D.compute_cell_extents(n) for n in sampled_voronoi_nuclei]
sampled_vs = results['voronoi.vs']
interp_depths = np.linspace(0, 160, 160)
statistics_vs = Voronoi1D.get_depth_profiles_statistics(
    sampled_thickness, sampled_vs, interp_depths
    )

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(6, 8), gridspec_kw={'width_ratios': [2.5, 1]})
ax1, cbar = Voronoi1D.plot_depth_profile_density(
    sampled_thickness, sampled_vs, ax=ax1, cmap='binary', vmin=0, vmax=2000
)
Voronoi1D.plot_depth_profile(THICKNESS, VS, ax=ax1, color='yellow', lw=3, label='True Vs')
ax1.plot(statistics_vs['mean'], interp_depths, 'b', lw=2, label='Vs Ensemble Mean')
ax1.plot(statistics_vs['median'], interp_depths, 'r', lw=2, label='Vs Ensemble Median')
ax1.set_xlabel("Vs [km/s]")
ax1.set_ylabel("Depth [km]")
ax1.legend()

Voronoi1D.plot_interface_hist(sampled_thickness, bins=75, ec='w', ax=ax2)
ax2.tick_params(labelleft=False)
ax2.set_ylabel('')
ax2.set_ylim(*ax1.get_ylim())
plt.tight_layout()
plt.show()

# %%
rayleigh_pred = np.array(results['rayleigh.dpred'])
love_pred = np.array(results['love.dpred'])
rayleigh_percentiles = np.percentile(rayleigh_pred, (10, 90), axis=0)
love_percentiles = np.percentile(love_pred, (10, 90), axis=0)

# Predicted dispersion curves

fig, ax = plt.subplots(1, 1, figsize=(7, 4))
ax.plot(PERIODS, rayleigh, 'r--', label='Rayleigh (True Vs)', lw=0.5)
ax.plot(PERIODS, rayleigh_obs, 'ro', label='Rayleigh Obs.')
ax.fill_between(PERIODS, rayleigh_percentiles[0], rayleigh_percentiles[1], color='r', alpha=0.2, label='Inferred Rayleigh (10th-90th percentiles)', zorder=100)
ax.plot(PERIODS, love, 'b--', label='Love (True Vs)', lw=0.5)
ax.plot(PERIODS, love_obs, 'bo', label='Love Obs.')
ax.fill_between(PERIODS, love_percentiles[0], love_percentiles[1], color='b', alpha=0.2, label='Inferred Love (10th-90th percentiles)', zorder=100)
ax.set_xlabel('Period [s]')
ax.set_ylabel('Phase velocity [km/s]')
ax.grid()
ax.legend()
plt.show()

# %%
# Histograms of inferred data noise

std_min = target_rayleigh.std_min
std_max = target_rayleigh.std_max

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 5))
ax1.axvline(x=RAYLEIGH_STD, color='r', lw=3, alpha=0.3, label='True data noise', zorder=0)
pdf, bins, _ = ax1.hist(results['rayleigh.std'], density=True, bins=20, ec='w', label='Posterior')
ax1.fill_between([std_min, std_max], 1 / (std_max - std_min), alpha=0.2, label='Prior')
ax1.set_xlabel('Noise standard deviation')
ax1.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
ax1.legend(framealpha=0.9, loc='upper right')
ax1.set_title('Rayleigh')

ax2.axvline(x=LOVE_STD, color='r', lw=3, alpha=0.3, label='True data noise', zorder=0)
pdf, bins, _ = ax2.hist(results['love.std'], density=True, bins=20, ec='w',  label='Posterior')
ax2.fill_between([std_min, std_max], 1 / (std_max - std_min), alpha=0.2, label='Prior')
ax2.set_xlabel('Noise standard deviation')
ax2.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
ax2.legend(framealpha=0.9, loc='upper right')
ax2.set_title('Love')

plt.tight_layout()
plt.show()

# %%
def get_subplot_layout(n_subplots):
    rows = int(np.sqrt(n_subplots))
    cols = int(np.ceil(n_subplots / rows))
    return rows, cols

rows, cols = get_subplot_layout(len(inversion.chains))
fig, axes = plt.subplots(rows, cols, figsize=(15, 15))
for ipanel, (ax, chain) in enumerate(zip(np.ravel(axes), inversion.chains)):
    saved_states = chain.saved_states
    saved_thickness = saved_states["voronoi.discretization"]
    saved_vs = saved_states['voronoi.vs']
    
    Voronoi1D.plot_depth_profiles(
    saved_thickness, saved_vs, ax=ax, linewidth=0.1, color="k", max_depth=150
)
    Voronoi1D.plot_depth_profile(THICKNESS, VS, color='yellow', lw=2, ax=ax)
    Voronoi1D.plot_depth_profiles_statistics(
        saved_thickness, saved_vs, interp_depths, ax=ax
    )
    
    ax.set_title(f'Chain {chain.id}')
    ax.tick_params(direction='in', labelleft=False, labelbottom=False)
    ax.set_xlabel('')
    ax.set_ylabel('')
    
    if not ipanel % cols:
        ax.set_ylabel('Depth [km]')
        ax.tick_params(labelleft=True)
    if ipanel >= (rows-1) * cols:
        ax.set_xlabel('Vs [km/s]')
        ax.tick_params(labelbottom=True)
    
plt.tight_layout()
plt.show()
