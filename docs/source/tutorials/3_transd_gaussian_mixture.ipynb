# %% [markdown]
# (transd_gaussian_mixture)=
# # Trans-dimensional Gaussian mixture model
#
# In this tutorial, we demonstrate how to use BayesBay to retrieve a Gaussian Mixture Model (GMM) while treating the number of components in the mixture as unknown. GMMs rest on the assumption that a complex probability distribution can be decomposed into simpler Gaussian distributions. By the weighted sum of these individual Gaussians, GMMs enable the calculation of the probability density function (PDF)
# $$f(x) = \sum_{i=1}^N \omega_i \cdot \mathcal{N}(x; \mu_i, \sigma_i),$$
#
# where $\mu_i$ and $\sigma_i$ denote the mean and standard deviation of the $i$th Gaussian, $\mathcal{N}(x; \mu_i, \sigma_i)$, and the weights are chosen such that $\sum_{i=1}^N \omega_i = 1$.
#
# GMMs are particularly useful to analyze datasets whose underlying distribution is a combination of different Gaussians. This is a common scenario in real-world data, where the considered statistical population often comprises several distinct subpopulations, each characterized by its own distribution. For example, imagine you have the following height measurements from a mixed group of adults and children:
#
# 1. **Children (Aged 8 to 12 years)**
#    - Measurements: 4000
#    - Mean height: 140 cm
#    - Standard deviation: 12 cm
# 2. **Adult Women**
#    - Measurements: 3000
#    - Mean height: 162 cm
#    - Standard deviation: 5 cm
# 3. **Adult Men**
#    - Measurements: 3000
#    - Mean height: 177 cm
#    - Standard deviation: 6 cm
#
#
# The height distribution for the above subgroups each follows a Gaussian distribution, but the combined dataset will have three peaks, which cannot be accurately modeled by a single Gaussian. A GMM can model this dataset as a combination of three Gaussians, each capturing the distribution of one subgroup &ndash; children, adult women, and adult men.

# %%
import bayesbay as bb
from math import sqrt, pi
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(31)

# %%
MEANS = [140, 162, 177]  # Means of the Gaussians
STDS = [12, 5, 6]  # Standard deviations of the Gaussians
WEIGHTS = [0.4, 0.3, 0.3]  # Weights of each Gaussian in the mixture
N_SAMPLES = 50_000 # Number of samples to generate

# %%
def gaussian(x, mu, sigma):
    return 1 / (sigma * sqrt(2*pi)) * np.exp(-0.5 * ((x - mu) / sigma)**2)

# %% [markdown]
# ## The dataset

# %%
assert np.isclose(sum(WEIGHTS), 1), "The weights must sum to 1."

def generate_random_samples(means, stds, weights):
    """Generate random samples for each component of the Gaussian mixture"""
    samples = []
    for mean, std, weight in zip(means, stds, weights):
        n_samples = int(N_SAMPLES * weight) # number of samples for each component
        samples.append(np.random.normal(mean, std, n_samples))
    samples = np.concatenate(samples)
    np.random.shuffle(samples)
    return samples

samples = generate_random_samples(MEANS, STDS, WEIGHTS)

# %%
# Define the range of x-values (i.e., heights) over which to evaluate the PDF
x_min, x_max = min(MEANS) - 3 * max(STDS), max(MEANS) + 3 * max(STDS)
xs = np.linspace(x_min, x_max, 1000)

pdf_true = np.zeros_like(xs)
for mean, std, weight in zip(MEANS, STDS, WEIGHTS):
    pdf_true += weight * gaussian(xs, mean, std)

# %%
fig, ax = plt.subplots()
ax.set_title('Histogram of measured heights')
data_obs, bins, _ = ax.hist(samples, bins=50, density=True, ec='w')
data_x = (bins[:-1] + bins[1:]) / 2 # take the midpoint of each bin
plt.plot(xs, pdf_true, label='True mixture PDF', color='r')
plt.plot(data_x, data_obs, 'ko', label='Observed data', markerfacecolor='None')

ax.set_xlabel('Height')
ax.set_ylabel('Density')
ax.grid()
ax.legend()
plt.show()

# %% [markdown]
# ## Setting up the Bayesian sampling
#
# To solve the inverse problem inherent in inferring the weights, mean heights, and standard deviations of the Gaussian mixture (henceforth, $\boldsymbol{\omega}$, $\boldsymbol{\mu}$, and $\boldsymbol{\sigma}$), we need to define:
#
# * A [Parameterization](../api/generated/bayesbay.parameterization.Parameterization), encapsulating the unknown model parameters $\mathbf{m} = [ \boldsymbol{\omega}, \boldsymbol{\mu}, \boldsymbol{\sigma}]$ and their prior probability
# * A *forward function*, enabling the prediction of data points $\mathbf{d}_{pred}$ from the model $\mathbf{m}$
# * What we refer to as a [Target](../api/generated/bayesbay.Target), that is, a Python object designed to store all information about a given data set
#
# ### **Prior probability**
#
# Here, we treat the number of Gaussians in the mixture as unknown and assume that
# * $100 \leq \mu_i \leq 200$ cm
# * $1 \leq \sigma_i \leq 20$ cm
# * $0 \leq \omega_i \leq 1$.
#
# In BayesBay, the above prior information can be implemented through [UniformParameter](../api/generated/bayesbay.parameters.UniformParameter), that is, a free parameter characterized by a uniform prior probability. (Different options for the prior of a free parameter can be implemented via [GaussianParameter](../api/generated/bayesbay.parameters.GaussianParameter) or [CustomParameter](../api/generated/bayesbay.parameters.CustomParameter).)
#
# Finally, note the argument ``perturb_std`` in the below block, taken by `UniformParameter`. The numerical value assigned to this argument represents the standard deviation of the Gaussian used to propose a new model by perturbing the considered parameter at a given Markov-chain iteration.

# %%
mean = bb.parameters.UniformParameter(name="mean", vmin=100, vmax=200, perturb_std=1)
std = bb.parameters.UniformParameter(name="std", vmin=1, vmax=20, perturb_std=1)
weight = bb.parameters.UniformParameter(name="weight", vmin=0, vmax=1, perturb_std=0.05)

# %% [markdown]
# ### **Parameter space and parameterization**
#
# The above free parameters should be used in BayesBay to create what we call a [ParameterSpace](../api/generated/bayesbay.parameterization.ParameterSpace). Mathematically, `ParameterSpace` can be thought of as a $n$-dimensional vector space. Each point (vector) within this space corresponds to a free parameter in the inference problem, and the position of each point defines the model parameters $\mathbf{m}_i \in \mathbb{R}^n$, with $\mathbf{m}_i \subseteq \mathbf{m}$. In this tutorial, $n$ is treated as unknown, giving rise to a trans-dimensional inversion. This is achieved by setting `n_dimensions=None` in the following block.
#
# From a computer programming perspective, `ParameterSpace` could be seen as a specialized container that not only groups a number of free parameters but also determines their dimensionality. For instance, in this tutorial's case, `ParameterSpace` will contain three distinct free parameters (namely, $\boldsymbol{\omega}$, $\boldsymbol{\mu}$, and $\boldsymbol{\sigma}$). Each of these parameters is a vector, the dimensionality of which matches that of `ParameterSpace` throughout the inversion process. In other words, each time a dimension is added to or removed from `ParameterSpace` (via a [BirthPerturbation](../api/generated/bayesbay.perturbations.BirthPerturbation)/[DeathPerturbation](../api/generated/bayesbay.perturbations.DeathPerturbation)), the dimensionality of the free parameters linked to it is adjusted accordingly. Additionally, `ParameterSpace` underpins the perturbation functions used propose new model parameters at a given Markov chain iteration from the current ones (for more information, see the module [bayesbridge.perturbations](../api/api_standard_perturbations)).
#
# Having defined one or more instances of `ParameterSpace`, these should be used to define a [Parameterization](../api/generated/bayesbay.parameterization.Parameterization). `Parameterization` is a relatively simple object compared to `ParameterSpace`, and its main purpose is to aggregate all model parameters (from all specified instances of `ParameterSpace`) to define $\mathbf{m} = \lbrace \mathbf{m}_1, \mathbf{m}_2, \mathbf{m}_3, \dots \rbrace$.

# %%
param_space = bb.parameterization.ParameterSpace(
    name="my_param_space", 
    n_dimensions=None, 
    n_dimensions_min=1,
    n_dimensions_max=7,
    parameters=[mean, std, weight], 
)
parameterization = bb.parameterization.Parameterization(param_space)

# %% [markdown]
# ### **Forward problem**
#
# Another fundamental ingredient in BayesBay is the definition of the forward function. This function is required to return the predicted data in the form of a numpy array, which is then used to calculate the likelihood $p({\bf d}_{obs} \mid {\bf m})$. The forward function should be programmed to take in a [bayesbay.State](../api/generated/bayesbay.State), from which all model parameters can be accessed. Within the forward function passed to BayesBay, function calls to external functions, as illustrated in the code block below, are of course allowed.

# %%
def _forward(means, stds, weights):
    weights /= np.sum(weights)
    data_pred = np.zeros_like(data_x)
    for i in range(len(means)):
        data_pred += weights[i] * gaussian(data_x, means[i], stds[i])
    return data_pred

def fwd_function(state: bb.State) -> np.ndarray:
    means = state["my_param_space"]['mean']
    stds = state["my_param_space"]['std']
    weights = state["my_param_space"]['weight']
    return _forward(means, stds, weights)

# %% [markdown]
# ### **Observed data: the Target**
#
# In BayesBay, the observed data should be used to define what we call a data [Target](../api/api_standard_target), which allows for treating the data noise as an unknown. This is accomplished by specifying minimum and maximum bounds for the standard deviation of the data and, optionally, for the data correlation. In this instance, we assume that there is no correlation between adjacent data points.

# %%
target = bb.Target("my_data", 
                   data_obs, 
                   # covariance_mat_inv=1/(1.25e-3)**2,
                   std_min=0, 
                   std_max=0.01, 
                   std_perturb_std=0.001,
                   noise_is_correlated=True)

# %% [markdown]
# ## Run the Bayesian sampling
#
# We can now use all the defined variables to solve the inference problem. The code provided below is self-explanatory. We sample the posterior using ten Markov chains, each run on a separate CPU for 50,000 iterations. The 2,000 iterations are discarded as the burn-in phase. After the burn-in, we save one model every 500 iterations.
#
#
# Notice the arguments ``targets`` and ``fwd_functions`` of [bayesbay.BayesianInversion](../api/generated/bayesbay.BayesianInversion): rather than accepting only one data target and forward function, as defined earlier, these can accept a list of targets and a list of functions. This flexibility makes it straightforward to carry out joint inversions of multiple datasets, each potentially associated with different forward functions.

# %%
inversion = bb.BayesianInversion(
    parameterization=parameterization, 
    targets=target, 
    fwd_functions=fwd_function, 
    n_chains=10, 
    n_cpus=10
)
inversion.run(
    sampler=bb.samplers.SimulatedAnnealing(temperature_start=3),
    n_iterations=250_000, 
    burnin_iterations=150_000, 
    save_every=500, 
    print_every=50_000,
    verbose=True, 
)
# Out:
# Chain ID: 0
# TEMPERATURE: 2.080099057812024
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 1691/50000 (3.38 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 175/12617 (1.39%)
# 	DeathPerturbation(my_param_space): 173/12431 (1.39%)
# 	NoisePerturbation(my_data): 785/12542 (6.26%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 558/12410 (4.50%)
# Chain ID: 9
# TEMPERATURE: 2.080099057812024
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 2480/50000 (4.96 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 288/12425 (2.32%)
# 	DeathPerturbation(my_param_space): 287/12511 (2.29%)
# 	NoisePerturbation(my_data): 830/12495 (6.64%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 1075/12569 (8.55%)
# Chain ID: 2
# TEMPERATURE: 2.080099057812024
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 2015/50000 (4.03 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 199/12547 (1.59%)
# 	DeathPerturbation(my_param_space): 197/12363 (1.59%)
# 	NoisePerturbation(my_data): 842/12566 (6.70%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 777/12524 (6.20%)
# Chain ID: 6
# TEMPERATURE: 2.080099057812024
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 1552/50000 (3.10 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 161/12341 (1.30%)
# 	DeathPerturbation(my_param_space): 159/12585 (1.26%)
# 	NoisePerturbation(my_data): 658/12513 (5.26%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 574/12561 (4.57%)
# Chain ID: 3
# TEMPERATURE: 2.080099057812024
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 2238/50000 (4.48 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 223/12302 (1.81%)
# 	DeathPerturbation(my_param_space): 220/12509 (1.76%)
# 	NoisePerturbation(my_data): 718/12651 (5.68%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 1077/12538 (8.59%)
# Chain ID: 7
# TEMPERATURE: 2.080099057812024
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 1662/50000 (3.32 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 155/12597 (1.23%)
# 	DeathPerturbation(my_param_space): 151/12528 (1.21%)
# 	NoisePerturbation(my_data): 636/12501 (5.09%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 720/12374 (5.82%)
# Chain ID: 1
# TEMPERATURE: 2.080099057812024
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 1671/50000 (3.34 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 168/12595 (1.33%)
# 	DeathPerturbation(my_param_space): 165/12385 (1.33%)
# 	NoisePerturbation(my_data): 688/12642 (5.44%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 650/12378 (5.25%)
# Chain ID: 5
# TEMPERATURE: 2.080099057812024
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 1818/50000 (3.64 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 195/11360 (1.72%)
# 	DeathPerturbation(my_param_space): 190/12840 (1.48%)
# 	NoisePerturbation(my_data): 678/13010 (5.21%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 755/12790 (5.90%)
# Chain ID: 4
# TEMPERATURE: 2.080099057812024
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 2073/50000 (4.15 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 248/12520 (1.98%)
# 	DeathPerturbation(my_param_space): 247/12511 (1.97%)
# 	NoisePerturbation(my_data): 679/12436 (5.46%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 899/12533 (7.17%)
# Chain ID: 8
# TEMPERATURE: 2.080099057812024
# EXPLORED MODELS: 50000
# ACCEPTANCE RATE: 1330/50000 (2.66 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 140/12353 (1.13%)
# 	DeathPerturbation(my_param_space): 137/12477 (1.10%)
# 	NoisePerturbation(my_data): 628/12604 (4.98%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 425/12566 (3.38%)
# Chain ID: 0
# TEMPERATURE: 1.4422601335000995
# EXPLORED MODELS: 100000
# ACCEPTANCE RATE: 2259/100000 (2.26 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 219/25100 (0.87%)
# 	DeathPerturbation(my_param_space): 217/24791 (0.88%)
# 	NoisePerturbation(my_data): 1221/25150 (4.85%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 602/24959 (2.41%)
# Chain ID: 2
# TEMPERATURE: 1.4422601335000995
# EXPLORED MODELS: 100000
# ACCEPTANCE RATE: 2605/100000 (2.60 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 252/25014 (1.01%)
# 	DeathPerturbation(my_param_space): 250/24886 (1.00%)
# 	NoisePerturbation(my_data): 1263/25110 (5.03%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 840/24990 (3.36%)
# Chain ID: 9
# TEMPERATURE: 1.4422601335000995
# EXPLORED MODELS: 100000
# ACCEPTANCE RATE: 3097/100000 (3.10 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 350/24866 (1.41%)
# 	DeathPerturbation(my_param_space): 348/25224 (1.38%)
# 	NoisePerturbation(my_data): 1218/25051 (4.86%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 1181/24859 (4.75%)
# Chain ID: 6
# TEMPERATURE: 1.4422601335000995
# EXPLORED MODELS: 100000
# ACCEPTANCE RATE: 2315/100000 (2.31 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 240/24865 (0.97%)
# 	DeathPerturbation(my_param_space): 238/25276 (0.94%)
# 	NoisePerturbation(my_data): 1102/24909 (4.42%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 735/24950 (2.95%)
# Chain ID: 1
# TEMPERATURE: 1.4422601335000995
# EXPLORED MODELS: 100000
# ACCEPTANCE RATE: 2415/100000 (2.42 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 212/25211 (0.84%)
# 	DeathPerturbation(my_param_space): 209/24843 (0.84%)
# 	NoisePerturbation(my_data): 1063/25105 (4.23%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 931/24841 (3.75%)
# Chain ID: 3
# TEMPERATURE: 1.4422601335000995
# EXPLORED MODELS: 100000
# ACCEPTANCE RATE: 2800/100000 (2.80 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 283/24874 (1.14%)
# 	DeathPerturbation(my_param_space): 280/25039 (1.12%)
# 	NoisePerturbation(my_data): 1111/25092 (4.43%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 1126/24995 (4.50%)
# Chain ID: 5
# TEMPERATURE: 1.4422601335000995
# EXPLORED MODELS: 100000
# ACCEPTANCE RATE: 2618/100000 (2.62 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 243/19719 (1.23%)
# 	DeathPerturbation(my_param_space): 238/26748 (0.89%)
# 	NoisePerturbation(my_data): 1124/26928 (4.17%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 1013/26605 (3.81%)
# Chain ID: 4
# TEMPERATURE: 1.4422601335000995
# EXPLORED MODELS: 100000
# ACCEPTANCE RATE: 2601/100000 (2.60 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 297/25123 (1.18%)
# 	DeathPerturbation(my_param_space): 296/24916 (1.19%)
# 	NoisePerturbation(my_data): 1054/24940 (4.23%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 954/25021 (3.81%)
# Chain ID: 7
# TEMPERATURE: 1.4422601335000995
# EXPLORED MODELS: 100000
# ACCEPTANCE RATE: 2540/100000 (2.54 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 209/25155 (0.83%)
# 	DeathPerturbation(my_param_space): 204/25037 (0.81%)
# 	NoisePerturbation(my_data): 1022/24878 (4.11%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 1105/24930 (4.43%)
# Chain ID: 2
# TEMPERATURE: 1.0000073241087457
# EXPLORED MODELS: 150000
# ACCEPTANCE RATE: 2972/150000 (1.98 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 290/37410 (0.78%)
# 	DeathPerturbation(my_param_space): 288/37536 (0.77%)
# 	NoisePerturbation(my_data): 1543/37698 (4.09%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 851/37356 (2.28%)
# Chain ID: 8
# TEMPERATURE: 1.4422601335000995
# EXPLORED MODELS: 100000
# ACCEPTANCE RATE: 1840/100000 (1.84 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 205/24728 (0.83%)
# 	DeathPerturbation(my_param_space): 202/24931 (0.81%)
# 	NoisePerturbation(my_data): 969/25282 (3.83%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 464/25059 (1.85%)
# Chain ID: 0
# TEMPERATURE: 1.0000073241087457
# EXPLORED MODELS: 150000
# ACCEPTANCE RATE: 2582/150000 (1.72 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 265/37426 (0.71%)
# 	DeathPerturbation(my_param_space): 263/37377 (0.70%)
# 	NoisePerturbation(my_data): 1433/37652 (3.81%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 621/37545 (1.65%)
# Chain ID: 9
# TEMPERATURE: 1.0000073241087457
# EXPLORED MODELS: 150000
# ACCEPTANCE RATE: 3554/150000 (2.37 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 392/37575 (1.04%)
# 	DeathPerturbation(my_param_space): 391/37519 (1.04%)
# 	NoisePerturbation(my_data): 1500/37602 (3.99%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 1271/37304 (3.41%)
# Chain ID: 6
# TEMPERATURE: 1.0000073241087457
# EXPLORED MODELS: 150000
# ACCEPTANCE RATE: 2822/150000 (1.88 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 303/37273 (0.81%)
# 	DeathPerturbation(my_param_space): 301/37775 (0.80%)
# 	NoisePerturbation(my_data): 1373/37527 (3.66%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 845/37425 (2.26%)
# Chain ID: 1
# TEMPERATURE: 1.0000073241087457
# EXPLORED MODELS: 150000
# ACCEPTANCE RATE: 3060/150000 (2.04 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 254/37778 (0.67%)
# 	DeathPerturbation(my_param_space): 251/37330 (0.67%)
# 	NoisePerturbation(my_data): 1325/37710 (3.51%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 1230/37182 (3.31%)
# Chain ID: 4
# TEMPERATURE: 1.0000073241087457
# EXPLORED MODELS: 150000
# ACCEPTANCE RATE: 2935/150000 (1.96 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 335/37741 (0.89%)
# 	DeathPerturbation(my_param_space): 334/37544 (0.89%)
# 	NoisePerturbation(my_data): 1286/37390 (3.44%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 980/37325 (2.63%)
# Chain ID: 7
# TEMPERATURE: 1.0000073241087457
# EXPLORED MODELS: 150000
# ACCEPTANCE RATE: 3240/150000 (2.16 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 251/37589 (0.67%)
# 	DeathPerturbation(my_param_space): 247/37535 (0.66%)
# 	NoisePerturbation(my_data): 1277/37368 (3.42%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 1465/37508 (3.91%)
# Chain ID: 2
# TEMPERATURE: 1
# EXPLORED MODELS: 200000
# ACCEPTANCE RATE: 3204/200000 (1.60 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 323/49921 (0.65%)
# 	DeathPerturbation(my_param_space): 321/50197 (0.64%)
# 	NoisePerturbation(my_data): 1699/50178 (3.39%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 861/49704 (1.73%)
# Chain ID: 8
# TEMPERATURE: 1.0000073241087457
# EXPLORED MODELS: 150000
# ACCEPTANCE RATE: 2173/150000 (1.45 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 263/37362 (0.70%)
# 	DeathPerturbation(my_param_space): 260/37334 (0.70%)
# 	NoisePerturbation(my_data): 1163/37734 (3.08%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 487/37570 (1.30%)
# Chain ID: 0
# TEMPERATURE: 1
# EXPLORED MODELS: 200000
# ACCEPTANCE RATE: 2857/200000 (1.43 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 297/49790 (0.60%)
# 	DeathPerturbation(my_param_space): 295/49805 (0.59%)
# 	NoisePerturbation(my_data): 1632/50342 (3.24%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 633/50063 (1.26%)
# Chain ID: 5
# TEMPERATURE: 1.0000073241087457
# EXPLORED MODELS: 150000
# ACCEPTANCE RATE: 2999/150000 (2.00 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 304/31917 (0.95%)
# 	DeathPerturbation(my_param_space): 299/39352 (0.76%)
# 	NoisePerturbation(my_data): 1333/39547 (3.37%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 1063/39184 (2.71%)
# Chain ID: 3
# TEMPERATURE: 1.0000073241087457
# EXPLORED MODELS: 150000
# ACCEPTANCE RATE: 3292/150000 (2.19 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 339/37334 (0.91%)
# 	DeathPerturbation(my_param_space): 335/37741 (0.89%)
# 	NoisePerturbation(my_data): 1370/37486 (3.65%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 1248/37439 (3.33%)
# Chain ID: 9
# TEMPERATURE: 1
# EXPLORED MODELS: 200000
# ACCEPTANCE RATE: 3787/200000 (1.89 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 432/49944 (0.86%)
# 	DeathPerturbation(my_param_space): 431/49983 (0.86%)
# 	NoisePerturbation(my_data): 1641/50141 (3.27%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 1283/49932 (2.57%)
# Chain ID: 6
# TEMPERATURE: 1
# EXPLORED MODELS: 200000
# ACCEPTANCE RATE: 3220/200000 (1.61 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 348/49972 (0.70%)
# 	DeathPerturbation(my_param_space): 346/50206 (0.69%)
# 	NoisePerturbation(my_data): 1626/50014 (3.25%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 900/49808 (1.81%)
# Chain ID: 1
# TEMPERATURE: 1
# EXPLORED MODELS: 200000
# ACCEPTANCE RATE: 3618/200000 (1.81 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 290/50324 (0.58%)
# 	DeathPerturbation(my_param_space): 286/49882 (0.57%)
# 	NoisePerturbation(my_data): 1504/50137 (3.00%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 1538/49657 (3.10%)
# Chain ID: 4
# TEMPERATURE: 1
# EXPLORED MODELS: 200000
# ACCEPTANCE RATE: 3191/200000 (1.60 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 374/50303 (0.74%)
# 	DeathPerturbation(my_param_space): 373/50127 (0.74%)
# 	NoisePerturbation(my_data): 1454/49786 (2.92%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 990/49784 (1.99%)
# Chain ID: 7
# TEMPERATURE: 1
# EXPLORED MODELS: 200000
# ACCEPTANCE RATE: 3807/200000 (1.90 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 291/50174 (0.58%)
# 	DeathPerturbation(my_param_space): 287/50063 (0.57%)
# 	NoisePerturbation(my_data): 1447/49727 (2.91%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 1782/50036 (3.56%)
# Chain ID: 2
# TEMPERATURE: 1
# EXPLORED MODELS: 250000
# ACCEPTANCE RATE: 3492/250000 (1.40 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 363/62394 (0.58%)
# 	DeathPerturbation(my_param_space): 361/62878 (0.57%)
# 	NoisePerturbation(my_data): 1892/62712 (3.02%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 876/62016 (1.41%)
# Chain ID: 8
# TEMPERATURE: 1
# EXPLORED MODELS: 200000
# ACCEPTANCE RATE: 2455/200000 (1.23 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 310/49818 (0.62%)
# 	DeathPerturbation(my_param_space): 307/49824 (0.62%)
# 	NoisePerturbation(my_data): 1330/50282 (2.65%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 508/50076 (1.01%)
# Chain ID: 0
# TEMPERATURE: 1
# EXPLORED MODELS: 250000
# ACCEPTANCE RATE: 3075/250000 (1.23 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 328/62294 (0.53%)
# 	DeathPerturbation(my_param_space): 326/62347 (0.52%)
# 	NoisePerturbation(my_data): 1783/62907 (2.83%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 638/62452 (1.02%)
# Chain ID: 5
# TEMPERATURE: 1
# EXPLORED MODELS: 200000
# ACCEPTANCE RATE: 3279/200000 (1.64 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 353/43943 (0.80%)
# 	DeathPerturbation(my_param_space): 348/52184 (0.67%)
# 	NoisePerturbation(my_data): 1481/52124 (2.84%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 1097/51749 (2.12%)
# Chain ID: 6
# TEMPERATURE: 1
# EXPLORED MODELS: 250000
# ACCEPTANCE RATE: 3535/250000 (1.41 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 392/62274 (0.63%)
# 	DeathPerturbation(my_param_space): 390/62698 (0.62%)
# 	NoisePerturbation(my_data): 1816/62621 (2.90%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 937/62407 (1.50%)
# Chain ID: 1
# TEMPERATURE: 1
# EXPLORED MODELS: 250000
# ACCEPTANCE RATE: 4206/250000 (1.68 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 332/62854 (0.53%)
# 	DeathPerturbation(my_param_space): 329/62525 (0.53%)
# 	NoisePerturbation(my_data): 1703/62521 (2.72%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 1842/62100 (2.97%)
# Chain ID: 3
# TEMPERATURE: 1
# EXPLORED MODELS: 200000
# ACCEPTANCE RATE: 3859/200000 (1.93 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 406/49656 (0.82%)
# 	DeathPerturbation(my_param_space): 403/50292 (0.80%)
# 	NoisePerturbation(my_data): 1574/50107 (3.14%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 1476/49945 (2.96%)
# Chain ID: 9
# TEMPERATURE: 1
# EXPLORED MODELS: 250000
# ACCEPTANCE RATE: 4049/250000 (1.62 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 469/62449 (0.75%)
# 	DeathPerturbation(my_param_space): 468/62588 (0.75%)
# 	NoisePerturbation(my_data): 1814/62630 (2.90%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 1298/62333 (2.08%)
# Chain ID: 4
# TEMPERATURE: 1
# EXPLORED MODELS: 250000
# ACCEPTANCE RATE: 3465/250000 (1.39 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 424/62894 (0.67%)
# 	DeathPerturbation(my_param_space): 423/62461 (0.68%)
# 	NoisePerturbation(my_data): 1618/62263 (2.60%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 1000/62382 (1.60%)
# Chain ID: 7
# TEMPERATURE: 1
# EXPLORED MODELS: 250000
# ACCEPTANCE RATE: 4262/250000 (1.70 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 341/62756 (0.54%)
# 	DeathPerturbation(my_param_space): 336/62479 (0.54%)
# 	NoisePerturbation(my_data): 1597/62152 (2.57%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 1988/62613 (3.18%)
# Chain ID: 8
# TEMPERATURE: 1
# EXPLORED MODELS: 250000
# ACCEPTANCE RATE: 2745/250000 (1.10 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 370/62216 (0.59%)
# 	DeathPerturbation(my_param_space): 367/62337 (0.59%)
# 	NoisePerturbation(my_data): 1481/62780 (2.36%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 527/62667 (0.84%)
# Chain ID: 5
# TEMPERATURE: 1
# EXPLORED MODELS: 250000
# ACCEPTANCE RATE: 3567/250000 (1.43 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 400/55914 (0.72%)
# 	DeathPerturbation(my_param_space): 395/64865 (0.61%)
# 	NoisePerturbation(my_data): 1640/64753 (2.53%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 1132/64468 (1.76%)
# Chain ID: 3
# TEMPERATURE: 1
# EXPLORED MODELS: 250000
# ACCEPTANCE RATE: 4203/250000 (1.68 %)
# PARTIAL ACCEPTANCE RATES:
# 	BirthPerturbation(my_param_space): 470/62141 (0.76%)
# 	DeathPerturbation(my_param_space): 466/62931 (0.74%)
# 	NoisePerturbation(my_data): 1758/62506 (2.81%)
# 	ParamPerturbation(['mean', 'std', 'weight']): 1509/62422 (2.42%)

# %% [markdown]
# ## Retrieve the results and plot

# %%
results = inversion.get_results()
print(results.keys())
# Out:
# dict_keys(['my_param_space.n_dimensions', 'mean', 'std', 'weight', 'my_data.std', 'my_data.correlation', 'dpred'])

# %%
n_gaussians = results['my_param_space.n_dimensions']
plt.hist(n_gaussians, bins=np.arange(1.5, 10.5), ec='w')
# Out:
# (array([  0., 787., 598., 333., 272.,  10.,   0.,   0.]),
#  array([1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5, 9.5]),
#  <BarContainer object of 8 artists>)

# %%
idx = [i for i, n_comp in enumerate(n_gaussians) if n_comp==4]

def sort_mixture(means, stds, weights):
    indexes = [np.argsort(row) for row in means]
    for i, idx in enumerate(indexes):
        means[i] = means[i][idx]
        stds[i] = stds[i][idx]
        weights[i] = weights[i][idx]
    return means, stds, weights

# %%
means, stds, weights = sort_mixture(np.array([results["mean"][i] for i in idx]), 
                                    np.array([results["std"][i] for i in idx]), 
                                    np.array([results["weight"][i] for i in idx]))

# %%
pdf_pred = _forward(np.median(means, axis=0), 
                    np.median(stds, axis=0), 
                    np.median(weights, axis=0)
                    )

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
ax1.hist(samples, bins=50, density=True, ec='w', fc='gray', alpha=0.8)
ax1.plot(xs, pdf_true, label='True mixture PDF', color='r')
ax1.plot(data_x, pdf_pred, label='Inferred', color='b')
ax1.set_xlabel('Height [cm]')
ax1.set_ylabel('Density')
ax1.legend()

ax2.hist(results['my_data.std'], bins=25, ec='w', zorder=100, label='Inferred')
ax2.set_xlabel('Noise standard deviation')
ax2.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
ax2.legend(framealpha=0.9)
plt.show()

# %%
np.median(means, axis=0)
# Out:
# array([139.52693937, 152.99219711, 162.23659983, 177.20071764])

# %%
np.median(stds, axis=0)
# Out:
# array([11.96156095, 10.99658724,  5.26375779,  6.03602457])

# %%
np.median(weights, axis=0)
# Out:
# array([0.37186035, 0.16328455, 0.29430035, 0.292309  ])
